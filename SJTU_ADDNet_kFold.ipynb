# %%
import os
import sys
import random
import mne
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from pytorch_metric_learning import losses
from torchsummary import summary

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, LabelBinarizer, normalize
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import KFold, StratifiedKFold
from scipy.stats import mode

import pandas as pd
import logging
import time
import math
import json
from collections import Counter

from datetime import datetime, timezone

from spikingjelly.activation_based import neuron, functional, surrogate, layer

from einops import rearrange, repeat, einsum

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = "cpu"

# %%
# f = mne.io.read_raw_edf("./Yingxf/Yingxf.edf")
# f = mne.io.read_raw_edf("./Liucx/Liucx.edf")

data_path = "./SJTU/Dingdw/Dingdw.edf"
raw_file = mne.io.read_raw_edf(data_path)
seiz_start_time = [
    datetime(2023, 5, 19, 21, 7, 16, tzinfo=timezone.utc),
    datetime(2023, 5, 19, 22, 9, 58, tzinfo=timezone.utc),
    datetime(2023, 5, 19, 23, 47, 8, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 0, 25, 59, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 1, 2, 11, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 1, 43, 13, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 4, 48, 44, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 6, 26, 6, tzinfo=timezone.utc)
]

seiz_end_time = [
    datetime(2023, 5, 19, 21, 9, 0, tzinfo=timezone.utc),
    datetime(2023, 5, 19, 22, 11, 18, tzinfo=timezone.utc),
    datetime(2023, 5, 19, 23, 49, 57, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 0, 27, 19, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 1, 4, 19, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 1, 53, 56, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 4, 54, 39, tzinfo=timezone.utc),
    datetime(2023, 5, 20, 6, 28, 4, tzinfo=timezone.utc)
]


# f = mne.io.read_raw_edf("./Chenzh/Chenzh.edf")
# f = mne.io.read_raw_edf("./Dingdw/Dingdw.edf")
# f = mne.io.read_raw_edf("./Dingdw/Suny.edf")
# f = mne.io.read_raw_edf("./Guljy/Guljy.edf")
# f = mne.io.read_raw_edf("./Xuyx/Xuyx.edf")
# f = mne.io.read_raw_edf("./Huangfs/Huangfs.edf")
# f = mne.io.read_raw_edf("./Majp/Majp.edf")
# Out:
# Extracting EDF parameters from E:\EEG\SJTU\Dingdw\Dingdw.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\95842\AppData\Local\Temp\ipykernel_3808\1262837694.py:5: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw_file = mne.io.read_raw_edf(data_path)
# C:\Users\95842\AppData\Local\Temp\ipykernel_3808\1262837694.py:5: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_file = mne.io.read_raw_edf(data_path)

# %%
# https://blog.csdn.net/cskywit/article/details/137448871
# https://github.com/johnma2006/mamba-minimal/blob/master/model.py

class MambaBlock(nn.Module):
    def __init__(self, input_channels):
        """A single Mamba block, as described in Figure 3 in Section 3.4 in the Mamba paper [1]."""
        super().__init__()

        self.d_model = input_channels
        self.d_inner = self.d_model * 2
        self.dt_rank = math.ceil(self.d_model / 16)
        self.d_state = 16
            
        self.in_proj = nn.Linear(self.d_model, self.d_inner * 2)#, bias=args.bias)

        self.conv1d = nn.Conv1d(
            in_channels=self.d_inner,
            out_channels=self.d_inner,
            # bias=args.conv_bias,
            kernel_size=3,
            groups=self.d_inner,
            padding=2,
        )

        # x_proj takes in `x` and outputs the input-specific Δ, B, C
        self.x_proj = nn.Linear(self.d_inner, self.dt_rank + self.d_state * 2, bias=False)
        
        # dt_proj projects Δ from dt_rank to d_in
        self.dt_proj = nn.Linear(self.dt_rank, self.d_inner, bias=True)

        A = repeat(torch.arange(1, self.d_state + 1), 'n -> d n', d=self.d_inner)
        self.A_log = nn.Parameter(torch.log(A))
        self.D = nn.Parameter(torch.ones(self.d_inner))
        self.out_proj = nn.Linear(self.d_inner, self.d_model) #, bias=args.bias)
        

    def forward(self, x):
        """Mamba block forward. This looks the same as Figure 3 in Section 3.4 in the Mamba paper [1].
    
        Args:
            x: shape (b, l, d)    (See Glossary at top for definitions of b, l, d_in, n...)
    
        Returns:
            output: shape (b, l, d)
        
        Official Implementation:
            class Mamba, https://github.com/state-spaces/mamba/blob/main/mamba_ssm/modules/mamba_simple.py#L119
            mamba_inner_ref(), https://github.com/state-spaces/mamba/blob/main/mamba_ssm/ops/selective_scan_interface.py#L311
            
        """
        (b, l, d) = x.shape
        
        x_and_res = self.in_proj(x)  # shape (b, l, 2 * d_in)
        (x, res) = x_and_res.split(split_size=[self.d_inner, self.d_inner], dim=-1)

        x = rearrange(x, 'b l d_in -> b d_in l')
        x = self.conv1d(x)[:, :, :l]
        x = rearrange(x, 'b d_in l -> b l d_in')
        
        x = F.silu(x)

        y = self.ssm(x)
        
        y = y * F.silu(res)
        
        output = self.out_proj(y)

        return output

    
    def ssm(self, x):
        """Runs the SSM. See:
            - Algorithm 2 in Section 3.2 in the Mamba paper [1]
            - run_SSM(A, B, C, u) in The Annotated S4 [2]

        Args:
            x: shape (b, l, d_in)    (See Glossary at top for definitions of b, l, d_in, n...)
    
        Returns:
            output: shape (b, l, d_in)

        Official Implementation:
            mamba_inner_ref(), https://github.com/state-spaces/mamba/blob/main/mamba_ssm/ops/selective_scan_interface.py#L311
            
        """
        (d_in, n) = self.A_log.shape

        # Compute ∆ A B C D, the state space parameters.
        #     A, D are input independent (see Mamba paper [1] Section 3.5.2 "Interpretation of A" for why A isn't selective)
        #     ∆, B, C are input-dependent (this is a key difference between Mamba and the linear time invariant S4,
        #                                  and is why Mamba is called **selective** state spaces)
        
        A = -torch.exp(self.A_log.float())  # shape (d_in, n)
        D = self.D.float()

        x_dbl = self.x_proj(x)  # (b, l, dt_rank + 2*n)
        
        (delta, B, C) = x_dbl.split(split_size=[self.dt_rank, n, n], dim=-1)  # delta: (b, l, dt_rank). B, C: (b, l, n)
        delta = F.softplus(self.dt_proj(delta))  # (b, l, d_in)
        
        y = self.selective_scan(x, delta, A, B, C, D)  # This is similar to run_SSM(A, B, C, u) in The Annotated S4 [2]
        
        return y

    
    def selective_scan(self, u, delta, A, B, C, D):
        """Does selective scan algorithm. See:
            - Section 2 State Space Models in the Mamba paper [1]
            - Algorithm 2 in Section 3.2 in the Mamba paper [1]
            - run_SSM(A, B, C, u) in The Annotated S4 [2]

        This is the classic discrete state space formula:
            x(t + 1) = Ax(t) + Bu(t)
            y(t)     = Cx(t) + Du(t)
        except B and C (and the step size delta, which is used for discretization) are dependent on the input x(t).
    
        Args:
            u: shape (b, l, d_in)    (See Glossary at top for definitions of b, l, d_in, n...)
            delta: shape (b, l, d_in)
            A: shape (d_in, n)
            B: shape (b, l, n)
            C: shape (b, l, n)
            D: shape (d_in,)
    
        Returns:
            output: shape (b, l, d_in)
    
        Official Implementation:
            selective_scan_ref(), https://github.com/state-spaces/mamba/blob/main/mamba_ssm/ops/selective_scan_interface.py#L86
            Note: I refactored some parts out of `selective_scan_ref` out, so the functionality doesn't match exactly.
            
        """
        (b, l, d_in) = u.shape
        n = A.shape[1]
        
        # Discretize continuous parameters (A, B)
        # - A is discretized using zero-order hold (ZOH) discretization (see Section 2 Equation 4 in the Mamba paper [1])
        # - B is discretized using a simplified Euler discretization instead of ZOH. From a discussion with authors:
        #   "A is the more important term and the performance doesn't change much with the simplification on B"
        deltaA = torch.exp(einsum(delta, A, 'b l d_in, d_in n -> b l d_in n'))
        deltaB_u = einsum(delta, B, u, 'b l d_in, b l n, b l d_in -> b l d_in n')
        
        # Perform selective scan (see scan_SSM() in The Annotated S4 [2])
        # Note that the below is sequential, while the official implementation does a much faster parallel scan that
        # is additionally hardware-aware (like FlashAttention).
        x = torch.zeros((b, d_in, n), device=deltaA.device)
        ys = []    
        for i in range(l):
            x = deltaA[:, i] * x + deltaB_u[:, i]
            y = einsum(x, C[:, i, :], 'b d_in n, b n -> b d_in')
            ys.append(y)
        y = torch.stack(ys, dim=1)  # shape (b, l, d_in)
        
        y = y + u * D
    
        return y

class RMSNorm(nn.Module):
    def __init__(self,
                 d_model: int,
                 eps: float = 1e-5):
        super().__init__()
        self.eps = eps
        self.weight = nn.Parameter(torch.ones(d_model))


    def forward(self, x):
        output = x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps) * self.weight

        return output

# %%
def compute_overlap(interval1, interval2):
    # Determine if there is an intersection
    if interval1[1] < interval2[0] or interval2[1] < interval1[0]:
        return 0
    
    # compute the start and the end of the overlap
    start = max(interval1[0], interval2[0])
    end = min(interval1[1], interval2[1])
    
    # compute the size of overlap
    overlap = end - start + 1
    
    return overlap

def check_overlap(interval1_np_list, interval2):
    # Determin if there is an intersection of length 0.1 s
    flag = True
    for i in range( len(interval1_np_list[0]) ):
        if compute_overlap([interval1_np_list[0][i], interval1_np_list[1][i]], interval2) >= NEW_SAMP_RATE/10:
            return i

    return -1



def get_names( ch_num, l ):
    name_list = []
    for i in range(ch_num):
        name_list.append( l[i]['name'] )
        # print(l[i]['name'][0])
    return name_list


def top_n_elements(lists, n=6):
    # 创建一个 Counter 对象以统计所有子列表中的元素
    overall_counter = Counter()
    
    # 遍历每个子列表并更新计数
    for sublist in lists:
        overall_counter.update(get_names(n, sublist))

    # 获取前 n 名元素
    top_elements_with_counts = overall_counter.most_common(n)

    top_elements = [element for element, count in top_elements_with_counts]
    counts = [count for element, count in top_elements_with_counts]
    
    return top_elements, counts

# %%
class ListMerger:
    def __init__(self, list1, list2):
        self.list1 = list1
        self.list2 = list2

    def __getitem__(self, index):
        if isinstance(index, slice):
            # 处理切片
            return [self[i] for i in range(*index.indices(len(self)))]
        elif index < len(self.list1):
            return self.list1[index]
        else:
            return self.list2[index - len(self.list1)]

    def __len__(self):
        # 返回合并后的列表的总长度
        return len(self.list1) + len(self.list2)

    def __iter__(self):
        return iter(self.list1 + self.list2)

class MergedDataset(Dataset):
    def __init__(self, merger, labels, indices):
        """
        :param merger: ListMerger 实例，包含合并后的数据
        :param indices: 要使用的索引列表
        """
        self.merger = merger
        self.labels = labels
        self.indices = indices

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        # 获取索引
        index = self.indices[idx]
        # 返回合并后的特征和标签
        return self.merger[index], self.labels[index]

def do_overlap( original_seq, seg_len, overlap_len ):
    '''
    Input:
        original_seq: 2d tensor, [ch, seq_len]
        overlap_len: float, overlapping length of 2 successive segments
    Outputs:
        res: a list of tensors
    '''
    res = []

    for i in range( 0, original_seq.shape[1], seg_len-overlap_len ):
        if original_seq.shape[1] - i < seg_len:
            break
        res.append( original_seq[:, i:(i+seg_len)] )

    return res

def read_SJTU_data( raw, seiz_start_time, seiz_end_time, COMMON_CH, SEG_TIME=4, OVERLAP=True ):
    # f = mne.io.read_raw_edf(data_folder)
    f = raw.copy()
    f.pick( COMMON_CH )
    data = f.get_data()
    data = data * 1e4
    
    meas_start_time = f.info['meas_date']#.strftime('%Y-%m-%d %H:%M:%S')
    sfreq = f.info['sfreq']
    all_channels = f.info['ch_names'][:-1] # drop last channels 'MK'
    
    SPH = int(30 * 60 * sfreq)
    SEG_LEN = int( SEG_TIME * sfreq )

    segments_pre = []
    segments_inter = []

    total_len_pre = 0
    total_len_inter = 0

    last_end = -1
    seiz_start_bias_time = []
    seiz_end_bias_time = []
    for i in range( len(seiz_start_time) ):
        seiz_start_bias_time.append( int((seiz_start_time[i] - meas_start_time).total_seconds() * sfreq) )
        seiz_end_bias_time.append( int((seiz_end_time[i] - meas_start_time).total_seconds() * sfreq) )

        beg = seiz_start_bias_time[i] - SPH
        end = seiz_start_bias_time[i]
        # print(beg, end)
        if beg < 0:
            segments_pre.append( torch.tensor(data[:, 0:seiz_start_bias_time[i]], dtype=torch.float32) )
            total_len_pre += seizure_start[i]
        else:
            segments_pre.append( torch.tensor(data[:, beg:end+1], dtype=torch.float32) )
            total_len_pre += segments_pre[-1].shape[1]
            segments_inter.append( torch.tensor(data[:, (last_end+1) : beg], dtype=torch.float32) )
            total_len_inter += segments_inter[-1].shape[1]
        last_end = seiz_end_bias_time[i]
        
    segments_inter.append( torch.tensor(data[:, (last_end+1):], dtype=torch.float32) ) 
    total_len_inter += segments_inter[-1].shape[1]
    # seiz_start_bias_time, seiz_end_bias_time
    
    segments_pre_overlap = []
    segments_inter_no_overlap = []
    step_for_overlap = int( SEG_LEN / ( total_len_inter / total_len_pre ) )
    print("step_for_overlap:", step_for_overlap)
    print(total_len_inter, total_len_pre)
    while segments_inter or segments_pre:
        if segments_pre:
            # segments_pre_overlap.append( do_overlap( seg_pre, SEG_LEN, OVERLAP_TIME*NEW_SAMP_RATE ) )
            if OVERLAP:
                segments_pre_overlap.extend( do_overlap( segments_pre[0], SEG_LEN, SEG_LEN-step_for_overlap) ) #OVERLAP_TIME*NEW_SAMP_RATE ) )
            else:
                segments_pre_overlap.extend( do_overlap( segments_pre[0], SEG_LEN, 0) )
            segments_pre.pop(0)
            # print( len(segments_pre_overlap) )
        if segments_inter:
            # segments_inter_no_overlap.append( do_overlap( segments_inter[0], SEG_LEN, OVERLAP_TIME*NEW_SAMP_RATE ) )
            segments_inter_no_overlap.extend( do_overlap( segments_inter[0], SEG_LEN, 0 ) )
            segments_inter.pop(0)
            # print( len(segments_inter_no_overlap) )
    
    
    return segments_inter_no_overlap, segments_pre_overlap

# %%
## https://www.kaggle.com/code/debarshichanda/pytorch-supervised-contrastive-learning
class SupervisedContrastiveLoss(nn.Module):
    def __init__(self, temperature=0.1):
        super(SupervisedContrastiveLoss, self).__init__()
        self.temperature = temperature

    def forward(self, feature_vectors, labels):
        # Normalize feature vectors
        feature_vectors_normalized = F.normalize(feature_vectors, p=2, dim=1)
        # Compute logits
        logits = torch.div(
            torch.matmul(
                feature_vectors_normalized, torch.transpose(feature_vectors_normalized, 0, 1)
            ),
            self.temperature,
        )
        # print( logits.shape, labels.shape )
        return losses.NTXentLoss(temperature=self.temperature)(logits, labels)
# super_contras = SupervisedContrastiveLoss(0.1)
# super_contras( x, label )

# %%
def count_label_np(one_hot_data, label):
    labels = np.argmax(one_hot_data, axis=1)  # 将one-hot编码转换为标签
    count = np.sum(labels == label)  # 统计标签出现的次数
    return count  

def calculate_accuracy_np(y_true, y_pred):
    labels_true = y_true #np.argmax(y_true, axis=1)  # 将真实标签转换为标签
    labels_pred = y_pred #np.argmax(y_pred, axis=1)  # 将预测结果转换为标签
    accuracy = np.sum(labels_true.T == labels_pred) / len(labels_true)  # 计算准确率
    return accuracy

def calculate_sensitivity_np(y_true, y_pred, class_index):
    # labels_true = np.argmax(y_true, axis=1)  # 将真实标签转换为标签
    # labels_pred = np.argmax(y_pred, axis=1)  # 将预测结果转换为标签
    labels_true = y_true #np.argmax(y_true, axis=1)  # 将真实标签转换为标签
    labels_pred = y_pred #np.argmax(y_pred, axis=1)  # 将预测结果转换为标签
    positive_labels = (labels_true == class_index)  # 将指定类别的标签设为1，其他类别设为0
    true_positive = np.sum((labels_pred == labels_true) * positive_labels)  # 统计真阳性的数量
    false_negative = np.sum((labels_pred != labels_true) * positive_labels)  # 统计假阴性的数量
    if (true_positive + false_negative) == 0:
        return -1
    sensitivity = true_positive / (true_positive + false_negative)  # 计算灵敏度
    return sensitivity

# %%
# 1 dimentional version + Mamba
## Patient-Specific Seizure Prediction via Adder Network and Supervised Contrastive Learning
## ADDNet-SCL-1d

class OneDCNN(nn.Module):
    def __init__(self, input_channels=3):
        super(OneDCNN, self).__init__()
        self.input_channels = input_channels
      
        self.conv1 = nn.Sequential(
            nn.Conv1d(in_channels=input_channels, out_channels=16, kernel_size=21, stride=1, padding=10),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=8, stride=8)
        )

        self.conv2_1 = nn.Sequential(
            nn.Conv1d(in_channels=16, out_channels=16, kernel_size=1, stride=1),
            nn.ReLU()
        )
        self.conv2_2 = nn.Sequential(
            nn.Conv1d(in_channels=16, out_channels=16, kernel_size=11, stride=1, padding=5),
            nn.ReLU(),
            nn.Conv1d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        self.pool3 = nn.MaxPool1d(kernel_size=4, stride=4)

        self.conv4_1 = nn.Sequential(
            nn.Conv1d(in_channels=16, out_channels=32, kernel_size=1, stride=2),
            nn.ReLU()
        )
        self.conv4_2 = nn.Sequential(
            nn.Conv1d(in_channels=16, out_channels=32, kernel_size=5, stride=2, padding=2),
            nn.ReLU(),
            nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        # self.conv5_1 = nn.Sequential(
        #     nn.Conv1d(in_channels=32, out_channels=32, kernel_size=1, stride=2),
        #     nn.ReLU()
        # )
        # self.conv5_2 = nn.Sequential(
        #     nn.Conv1d(in_channels=32, out_channels=32, kernel_size=5, stride=2, padding=2),
        #     nn.ReLU(),
        #     nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
        #     nn.ReLU()
        # )

        self.mixer = MambaBlock(32)
        self.norm = RMSNorm(32)

        self.adaptive_avg_pool = nn.AdaptiveAvgPool1d(output_size=1)
        
        self.classifier = nn.Sequential(
            nn.Linear(32, 2)
        )

    def forward(self, x):
        # x = x.unsqueeze(1)
        # print(x.shape)
        
        x = self.conv1(x)

        x = self.pool3( self.conv2_1(x)+self.conv2_2(x) )

        x = self.conv4_1(x)+self.conv4_2(x)

        # x = self.conv5_1(x)+self.conv5_2(x)

        # x = [batch, channels, seq_len]
        x = x.permute(0, 2, 1) # [batch, seq_len, channels]
        x = self.mixer(self.norm(x)) + x
        x = x.permute(0, 2, 1) # [batch, channels, seq_len]

        x = self.adaptive_avg_pool( x )
        
        x_digits = x.contiguous().view(x.size(0), -1)
        # print(f'x.shape = {x.shape}')
        x_res = self.classifier(x_digits)
        return x_res, x_digits

# %%
print('SJTU/'+os.path.basename(data_path).split('.')[0]+'_sel_ch_30iter_with_SMOTE.json')

with open('SJTU/'+os.path.basename(data_path).split('.')[0]+'_sel_ch_30iter_with_SMOTE.json', 'r') as json_file:
    loaded_data = json.load(json_file)
COMMON_CH, _ = top_n_elements( loaded_data, 8 ) # 8 channels are acceptable

log_file_name = 'SJTU/'+os.path.basename(data_path).split('.')[0]+'_'+str(len(COMMON_CH))+'chs_log_with_mamba_10fold.txt'
with open(log_file_name, "w") as f:
    f.write("AddNet-SCL With Mamba 1D - 10-fold\n" + str(len(COMMON_CH)) + " channels\n" )



# split the raw data to 4 sec segments
SEG_TIME = 4

logger = logging.getLogger('mne')
# logger.setLevel(logging.WARNING)
logger.setLevel(logging.ERROR) # 每读一个edf文件都会有一个通道名重复的警告

    
segments_inter, segments_pre = read_SJTU_data( raw_file, seiz_start_time, seiz_end_time, COMMON_CH, SEG_TIME=SEG_TIME, OVERLAP=True )

segments = ListMerger( segments_inter, segments_pre )
seg_labels = [0] * len(segments_inter) + [1] * len(segments_pre)
seg_labels = torch.nn.functional.one_hot(torch.tensor(seg_labels), num_classes=2)


kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
test_acc = []
test_sens = []
test_spec = []
for i, (train_index, test_index) in enumerate(kf.split(segments, seg_labels.argmax(axis=1))):
    # 获取训练和测试数据，都是np.array
    X_train_indices = train_index
    X_test_indices = test_index

    # 从训练集中划分出验证集
    val_size = int(len(X_train_indices) * 0.2)  # 20% 用作验证集
    val_indices = np.random.choice(X_train_indices, size=val_size, replace=False)
    train_indices = np.setdiff1d(X_train_indices, val_indices)

    # 创建数据集
    train_dataset = MergedDataset(segments, seg_labels, train_indices)
    val_dataset = MergedDataset(segments, seg_labels, val_indices)
    test_dataset = MergedDataset(segments, seg_labels, X_test_indices)

    # 创建数据加载器
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)#, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)#, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)#, pin_memory=True)
    # break

    best_test_accuracy = 0
    best_epoch = -1
    sens_p = 0
    spec_p = 0
    
    
    model = OneDCNN(len(COMMON_CH)).to(device)

    # criterion = nn.MSELoss().to(device)
    # criterion = nn.BCELoss().to(device)
    criterion = nn.CrossEntropyLoss().to(device)
    super_contras = SupervisedContrastiveLoss(0.08).to(device)
    # criterion = WeightedMSELoss(4).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    
    num_epochs = 30
    # VOTE_NUM = 5
    y_test = np.array(seg_labels[X_test_indices])
    y_test = np.argmax( y_test, axis=1)
    y_val = np.array(seg_labels[val_indices])
    y_val = np.argmax( y_val, axis=1)
    # y_test_flat = y_test[VOTE_NUM - 1:]
    for epoch in range(num_epochs):
        start_time = time.time()
        # 训练阶段
        model.train()
        
        train_loss = 0.0
        train_loss_cross = 0.0
        train_loss_cont  = 0.0
        
        correct = 0
        for interation, (inputs, targets) in enumerate(train_loader):
            # print(interation)
            
            inputs = inputs.to(device)
            targets = targets.to(device).float()
            outputs, feats = model(inputs)
            loss_cross = criterion(outputs, targets)
            tars = targets.argmax(dim=1)
            # print(tars.shape)
            loss_cont = super_contras( feats, tars )
            loss = 0.5 * loss_cross + 0.5 * loss_cont
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            # functional.reset_net( model )
    
            # print(outputs.shape, targets.shape)
            predicted = torch.argmax(outputs, dim=1) #(outputs > 0.5).float()
            targets = torch.argmax(targets, dim=1) #(targets>0.5).to(device)
            correct += (predicted == targets).sum().item()
    
            train_loss += loss.item()
            train_loss_cross += loss_cross.item()
            train_loss_cont  += loss_cont.item()
               
        train_loss /= len(train_loader)
        train_loss_cross /= len(train_loader)
        train_loss_cont /= len(train_loader)
        train_acc = correct / len(train_dataset)
    
    
        # 验证阶段
        model.eval()
        
        val_loss = 0.0
        val_loss_cross = 0.0
        val_loss_cont  = 0.0
        
        correct = 0
        total = 0
        TP = 0
        FN = 0
        TN = 0
        FP = 0
        predictions = []
        # targets = []
        with torch.inference_mode():
            for inputs, targets in val_loader:
                inputs = inputs.to(device)
                targets = targets.to(device).float()
                outputs, feats = model(inputs)
                predicted = torch.argmax(outputs, dim=1) #(outputs > 0.5).float()
                loss_cross = criterion(outputs, targets)
                tars = targets.argmax(dim=1)
                loss_cont = super_contras( feats, tars )
                loss = loss_cross + loss_cont
                
                val_loss += loss.item()
                val_loss_cross += loss_cross.item()
                val_loss_cont += loss_cont.item()
                
                predictions.extend( predicted.cpu() )
                
                # functional.reset_net( model )
    
            predictions = np.array( predictions )
            # final_predictions_flat = np.array( [ mode(predictions[ i-(VOTE_NUM-1) : i+1 ]).mode for i in range(VOTE_NUM-1, len(predictions)) ] )
            
            # 计算混淆矩阵的四个基本元素
            TP = np.sum((predictions == 1) & (y_val == 1))  # True Positives
            TN = np.sum((predictions == 0) & (y_val == 0))  # True Negatives
            FP = np.sum((predictions == 1) & (y_val == 0))  # False Positives
            FN = np.sum((predictions == 0) & (y_val == 1))  # False Negatives
            
                
                
        val_loss /= len(val_loader)
        val_loss_cross /= len(val_loader)
        val_loss_cont  /= len(val_loader)
        
        test_accuracy = (TP + TN) / (TP + TN + FP + FN)
        sens_p_epoch = TP / (TP + FN) if (TP+FN != 0 ) else 0
        spec_p_epoch = TN / (TN + FP) if (TN+FP != 0 ) else 0
    
        
        if test_accuracy > best_test_accuracy: # sens_p_epoch > sens_p:  
            best_test_accuracy = test_accuracy
            best_epoch = epoch
            sens_p = TP / (TP + FN) if (TP+FN != 0 ) else 0
            spec_p = TN / (TN + FP) if (TN+FP != 0 ) else 0
            torch.save(model, 'SJTU/'+os.path.basename(data_path).split('.')[0]+str(best_epoch)+'.pt')
        end_time = time.time()
        time_cost = end_time - start_time
        # print(f'\nEpoch [{epoch+1}/{num_epochs}], time cost: {time_cost:.4f},\n Train Cross Loss: {train_loss_cross:.4f}, Train Contras Loss: {train_loss_cont:.4f} Train acc: {train_acc: .4f},\n Val Cross loss: {val_loss_cross:.4f}, Val Contras loss: {val_loss_cont:.4f}, Test accuracy: {test_accuracy:.4f}, Sensitivity: {sens_p_epoch:.4f}, Specificity: {spec_p_epoch:.4f}, Test acc vote: {test_acc_vote:.4f}, Sens vote: {sens_p_epoch_vote:.4f}, Spec vote: {spec_p_epoch_vote:.4f}')
        training_info = f'\nFold [{i+1}/10] Epoch [{epoch+1}/{num_epochs}], time cost: {time_cost:.4f},\n Train Cross Loss: {train_loss_cross:.4f}, Train Contras Loss: {train_loss_cont:.4f} Train acc: {train_acc: .4f},\n Val Cross loss: {val_loss_cross:.4f}, Val Contras loss: {val_loss_cont:.4f}, Val accuracy: {test_accuracy:.4f}, Sensitivity: {sens_p_epoch:.4f}, Specificity: {spec_p_epoch:.4f}'
        print(training_info)
        with open(log_file_name, 'a') as f:
            f.write( training_info+'\n' )
    

    train_summary = ', '.join(COMMON_CH)
    train_summary = train_summary + f'\n***********")\nBest epoch: {best_epoch}, Acc: {best_test_accuracy}, Sensitivity for pre-ictal: {sens_p}, Specificity: {spec_p}\n***********\n'
    with open(log_file_name, 'a') as f:
        f.write( train_summary )
    print(COMMON_CH)
    # print("***********\nSensitivity for pre-ictal:", sens_p, ", sensitivity for inter:", sens_inter)
    print("\n***********")
    print("Best epoch:", best_epoch, "Acc:", best_test_accuracy, "Sensitivity for pre-ictal:", sens_p, "Specificity:", spec_p)
    print("***********\n")


    model_for_test = torch.load( 'SJTU/'+os.path.basename(data_path).split('.')[0]+str(best_epoch)+'.pt' )
    model_for_test.eval()
    test_loss = 0.0
    correct = 0
    # total = 0
    TP = 0
    FN = 0
    TN = 0
    FP = 0
    predictions = []
    outputs_list = []
    with torch.inference_mode():
        for inputs, targets in test_loader:
            inputs = inputs.to(device)
            targets = targets.to(device).float()
    
            # print( inputs.shape, targets.shape )
            
            outputs, feats = model_for_test(inputs)
    
            # print( outputs.shape, targets )
            # break
            
            predicted = torch.argmax(outputs, dim=1) #(outputs >= 0.5).float()
            loss = criterion(outputs, targets)
            targets = torch.argmax(targets, dim=1)
            test_loss += loss.item()
            # total += targets.size(0)
            positive_labels = ( targets == 1 )
            correct += (predicted == targets).sum().item()
            TP += ( positive_labels * ( predicted == targets ) ).sum().item()
            FN += ( positive_labels * ( predicted != targets ) ).sum().item()
            # functional.reset_net( model )
    
            predictions.extend(predicted.cpu())
            outputs_list.extend(outputs.cpu())
            
            # print(predicted.shape, targets.shape)
            
            # break
    predictions = np.array( predictions)
    TP = np.sum((predictions == 1) & (y_test == 1))  # True Positives
    TN = np.sum((predictions == 0) & (y_test == 0))  # True Negatives
    FP = np.sum((predictions == 1) & (y_test == 0))  # False Positives
    FN = np.sum((predictions == 0) & (y_test == 1))  # False Negatives
        
    
    test_loss /= len(test_loader)
    test_accuracy = correct / len(test_dataset)
    test_sensitivity = TP / (TP + FN) if (TP+FN != 0 ) else 0
    test_specificity = TN / (TN + FP) if (TN+FP != 0 ) else 0

    test_info = f'Test Loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}, Sensitivity: {test_sensitivity:.4f}, Specificity: {test_specificity:.4f}'
    with open(log_file_name, 'a') as f:
        f.write( test_info )
    print(test_info)

    test_acc.append( test_accuracy )
    test_sens.append( test_sensitivity )
    test_spec.append( test_specificity )

    # break # only use 80-20 split for channel experiments

avg_test_info = f'\n\nAvg test acc: {sum(test_acc)/len(test_acc):.4f}, avg test sensitivity: {sum(test_sens)/len(test_sens):.4f}, avg test specificity: {sum(test_spec)/len(test_spec):.4f} \n'
with open(log_file_name, 'a') as f:
    f.write( avg_test_info )
print( avg_test_info )
# print( "Avg test acc:", sum(test_acc)/len(test_acc), "avg test sensitivity:", sum(test_sens)/len(test_sens), "avg test specificity", sum(test_spec)/len(test_spec) )
# Out:
# SJTU/Dingdw_sel_ch_30iter_with_SMOTE.json
# step_for_overlap: 119
# 7879544 1843208
#
# Fold [1/10] Epoch [1/30], time cost: 15.8769,
#  Train Cross Loss: 0.2893, Train Contras Loss: 1.5946 Train acc:  0.8910,
#  Val Cross loss: 0.1844, Val Contras loss: 1.0789, Val accuracy: 0.9447, Sensitivity: 0.9546, Specificity: 0.9347
#
# Fold [1/10] Epoch [2/30], time cost: 14.0364,
#  Train Cross Loss: 0.1565, Train Contras Loss: 0.9023 Train acc:  0.9481,
#  Val Cross loss: 0.1253, Val Contras loss: 0.6947, Val accuracy: 0.9593, Sensitivity: 0.9739, Specificity: 0.9445
#
# Fold [1/10] Epoch [3/30], time cost: 13.8811,
#  Train Cross Loss: 0.1332, Train Contras Loss: 0.7923 Train acc:  0.9537,
#  Val Cross loss: 0.1358, Val Contras loss: 0.8148, Val accuracy: 0.9530, Sensitivity: 0.9818, Specificity: 0.9238
#
# Fold [1/10] Epoch [4/30], time cost: 14.5079,
#  Train Cross Loss: 0.1174, Train Contras Loss: 0.6930 Train acc:  0.9589,
#  Val Cross loss: 0.1039, Val Contras loss: 0.6260, Val accuracy: 0.9587, Sensitivity: 0.9843, Specificity: 0.9328
#
# Fold [1/10] Epoch [5/30], time cost: 13.5027,
#  Train Cross Loss: 0.1032, Train Contras Loss: 0.5807 Train acc:  0.9651,
#  Val Cross loss: 0.1031, Val Contras loss: 0.5729, Val accuracy: 0.9651, Sensitivity: 0.9710, Specificity: 0.9590
#
# Fold [1/10] Epoch [6/30], time cost: 13.8481,
#  Train Cross Loss: 0.0990, Train Contras Loss: 0.5568 Train acc:  0.9675,
#  Val Cross loss: 0.1354, Val Contras loss: 0.7989, Val accuracy: 0.9521, Sensitivity: 0.9406, Specificity: 0.9637
#
# Fold [1/10] Epoch [7/30], time cost: 13.2927,
#  Train Cross Loss: 0.0940, Train Contras Loss: 0.5188 Train acc:  0.9673,
#  Val Cross loss: 0.0770, Val Contras loss: 0.4498, Val accuracy: 0.9733, Sensitivity: 0.9864, Specificity: 0.9601
#
# Fold [1/10] Epoch [8/30], time cost: 13.6887,
#  Train Cross Loss: 0.0881, Train Contras Loss: 0.4814 Train acc:  0.9701,
#  Val Cross loss: 0.0733, Val Contras loss: 0.4261, Val accuracy: 0.9750, Sensitivity: 0.9857, Specificity: 0.9641
#
# Fold [1/10] Epoch [9/30], time cost: 14.1816,
#  Train Cross Loss: 0.0788, Train Contras Loss: 0.4287 Train acc:  0.9736,
#  Val Cross loss: 0.0797, Val Contras loss: 0.4604, Val accuracy: 0.9742, Sensitivity: 0.9936, Specificity: 0.9546
#
# Fold [1/10] Epoch [10/30], time cost: 13.5935,
#  Train Cross Loss: 0.0786, Train Contras Loss: 0.4238 Train acc:  0.9742,
#  Val Cross loss: 0.0808, Val Contras loss: 0.4934, Val accuracy: 0.9728, Sensitivity: 0.9850, Specificity: 0.9604
#
# Fold [1/10] Epoch [11/30], time cost: 13.3301,
#  Train Cross Loss: 0.0776, Train Contras Loss: 0.4128 Train acc:  0.9733,
#  Val Cross loss: 0.0799, Val Contras loss: 0.4395, Val accuracy: 0.9708, Sensitivity: 0.9861, Specificity: 0.9554
#
# Fold [1/10] Epoch [12/30], time cost: 13.5374,
#  Train Cross Loss: 0.0714, Train Contras Loss: 0.3826 Train acc:  0.9755,
#  Val Cross loss: 0.0752, Val Contras loss: 0.4308, Val accuracy: 0.9728, Sensitivity: 0.9750, Specificity: 0.9706
#
# Fold [1/10] Epoch [13/30], time cost: 14.1359,
#  Train Cross Loss: 0.0679, Train Contras Loss: 0.3538 Train acc:  0.9773,
#  Val Cross loss: 0.0725, Val Contras loss: 0.3916, Val accuracy: 0.9771, Sensitivity: 0.9921, Specificity: 0.9619
#
# Fold [1/10] Epoch [14/30], time cost: 13.2249,
#  Train Cross Loss: 0.0718, Train Contras Loss: 0.3753 Train acc:  0.9750,
#  Val Cross loss: 0.0871, Val Contras loss: 0.4501, Val accuracy: 0.9723, Sensitivity: 0.9689, Specificity: 0.9757
#
# Fold [1/10] Epoch [15/30], time cost: 13.3197,
#  Train Cross Loss: 0.0682, Train Contras Loss: 0.3524 Train acc:  0.9769,
#  Val Cross loss: 0.0938, Val Contras loss: 0.5244, Val accuracy: 0.9654, Sensitivity: 0.9596, Specificity: 0.9713
#
# Fold [1/10] Epoch [16/30], time cost: 13.0323,
#  Train Cross Loss: 0.0617, Train Contras Loss: 0.3199 Train acc:  0.9785,
#  Val Cross loss: 0.0749, Val Contras loss: 0.4069, Val accuracy: 0.9769, Sensitivity: 0.9825, Specificity: 0.9713
#
# Fold [1/10] Epoch [17/30], time cost: 13.1822,
#  Train Cross Loss: 0.0628, Train Contras Loss: 0.3280 Train acc:  0.9791,
#  Val Cross loss: 0.0662, Val Contras loss: 0.3748, Val accuracy: 0.9773, Sensitivity: 0.9918, Specificity: 0.9626
#
# Fold [1/10] Epoch [18/30], time cost: 13.5011,
#  Train Cross Loss: 0.0576, Train Contras Loss: 0.2989 Train acc:  0.9805,
#  Val Cross loss: 0.0741, Val Contras loss: 0.3865, Val accuracy: 0.9728, Sensitivity: 0.9900, Specificity: 0.9554
#
# Fold [1/10] Epoch [19/30], time cost: 13.0823,
#  Train Cross Loss: 0.0610, Train Contras Loss: 0.3023 Train acc:  0.9805,
#  Val Cross loss: 0.0685, Val Contras loss: 0.3480, Val accuracy: 0.9768, Sensitivity: 0.9903, Specificity: 0.9630
#
# Fold [1/10] Epoch [20/30], time cost: 13.3666,
#  Train Cross Loss: 0.0567, Train Contras Loss: 0.2807 Train acc:  0.9814,
#  Val Cross loss: 0.0868, Val Contras loss: 0.4272, Val accuracy: 0.9663, Sensitivity: 0.9936, Specificity: 0.9387
#
# Fold [1/10] Epoch [21/30], time cost: 14.2749,
#  Train Cross Loss: 0.0588, Train Contras Loss: 0.2896 Train acc:  0.9810,
#  Val Cross loss: 0.0622, Val Contras loss: 0.3235, Val accuracy: 0.9784, Sensitivity: 0.9886, Specificity: 0.9681
#
# Fold [1/10] Epoch [22/30], time cost: 13.4638,
#  Train Cross Loss: 0.0560, Train Contras Loss: 0.2828 Train acc:  0.9817,
#  Val Cross loss: 0.0690, Val Contras loss: 0.3582, Val accuracy: 0.9784, Sensitivity: 0.9911, Specificity: 0.9655
#
# Fold [1/10] Epoch [23/30], time cost: 13.5960,
#  Train Cross Loss: 0.0567, Train Contras Loss: 0.2846 Train acc:  0.9812,
#  Val Cross loss: 0.0680, Val Contras loss: 0.3433, Val accuracy: 0.9807, Sensitivity: 0.9882, Specificity: 0.9731
#
# Fold [1/10] Epoch [24/30], time cost: 13.8236,
#  Train Cross Loss: 0.0487, Train Contras Loss: 0.2414 Train acc:  0.9835,
#  Val Cross loss: 0.0581, Val Contras loss: 0.3058, Val accuracy: 0.9816, Sensitivity: 0.9878, Specificity: 0.9753
#
# Fold [1/10] Epoch [25/30], time cost: 13.9873,
#  Train Cross Loss: 0.0546, Train Contras Loss: 0.2696 Train acc:  0.9828,
#  Val Cross loss: 0.1132, Val Contras loss: 0.5292, Val accuracy: 0.9660, Sensitivity: 0.9614, Specificity: 0.9706
#
# Fold [1/10] Epoch [26/30], time cost: 13.5934,
#  Train Cross Loss: 0.0518, Train Contras Loss: 0.2645 Train acc:  0.9827,
#  Val Cross loss: 0.0535, Val Contras loss: 0.2891, Val accuracy: 0.9827, Sensitivity: 0.9850, Specificity: 0.9804
#
# Fold [1/10] Epoch [27/30], time cost: 13.2636,
#  Train Cross Loss: 0.0480, Train Contras Loss: 0.2348 Train acc:  0.9847,
#  Val Cross loss: 0.0531, Val Contras loss: 0.2793, Val accuracy: 0.9831, Sensitivity: 0.9903, Specificity: 0.9757
#
# Fold [1/10] Epoch [28/30], time cost: 13.5233,
#  Train Cross Loss: 0.0520, Train Contras Loss: 0.2560 Train acc:  0.9832,
#  Val Cross loss: 0.0503, Val Contras loss: 0.2644, Val accuracy: 0.9814, Sensitivity: 0.9936, Specificity: 0.9691
#
# Fold [1/10] Epoch [29/30], time cost: 14.1722,
#  Train Cross Loss: 0.0448, Train Contras Loss: 0.2210 Train acc:  0.9847,
#  Val Cross loss: 0.0665, Val Contras loss: 0.3370, Val accuracy: 0.9800, Sensitivity: 0.9957, Specificity: 0.9641
#
# Fold [1/10] Epoch [30/30], time cost: 14.5852,
#  Train Cross Loss: 0.0495, Train Contras Loss: 0.2373 Train acc:  0.9846,
#  Val Cross loss: 0.0707, Val Contras loss: 0.3456, Val accuracy: 0.9791, Sensitivity: 0.9839, Specificity: 0.9742
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 26 Acc: 0.9830661142136552 Sensitivity for pre-ictal: 0.990343347639485 Specificity: 0.9756805807622505
# ***********
#
# Test Loss: 0.0627, Test accuracy: 0.9812, Sensitivity: 0.9909, Specificity: 0.9714
#
# Fold [2/10] Epoch [1/30], time cost: 13.5841,
#  Train Cross Loss: 0.2819, Train Contras Loss: 1.5457 Train acc:  0.8865,
#  Val Cross loss: 0.1714, Val Contras loss: 1.0536, Val accuracy: 0.9395, Sensitivity: 0.9769, Specificity: 0.9009
#
# Fold [2/10] Epoch [2/30], time cost: 13.9430,
#  Train Cross Loss: 0.1404, Train Contras Loss: 0.8348 Train acc:  0.9497,
#  Val Cross loss: 0.1337, Val Contras loss: 0.8083, Val accuracy: 0.9566, Sensitivity: 0.9787, Specificity: 0.9338
#
# Fold [2/10] Epoch [3/30], time cost: 13.5312,
#  Train Cross Loss: 0.1257, Train Contras Loss: 0.7174 Train acc:  0.9574,
#  Val Cross loss: 0.1043, Val Contras loss: 0.5999, Val accuracy: 0.9651, Sensitivity: 0.9844, Specificity: 0.9451
#
# Fold [2/10] Epoch [4/30], time cost: 13.6973,
#  Train Cross Loss: 0.1152, Train Contras Loss: 0.6676 Train acc:  0.9596,
#  Val Cross loss: 0.1106, Val Contras loss: 0.6626, Val accuracy: 0.9595, Sensitivity: 0.9791, Specificity: 0.9393
#
# Fold [2/10] Epoch [5/30], time cost: 13.5764,
#  Train Cross Loss: 0.1059, Train Contras Loss: 0.6040 Train acc:  0.9651,
#  Val Cross loss: 0.1413, Val Contras loss: 0.7880, Val accuracy: 0.9454, Sensitivity: 0.9443, Specificity: 0.9466
#
# Fold [2/10] Epoch [6/30], time cost: 13.3140,
#  Train Cross Loss: 0.0982, Train Contras Loss: 0.5410 Train acc:  0.9670,
#  Val Cross loss: 0.0813, Val Contras loss: 0.4645, Val accuracy: 0.9741, Sensitivity: 0.9869, Specificity: 0.9609
#
# Fold [2/10] Epoch [7/30], time cost: 13.1831,
#  Train Cross Loss: 0.0924, Train Contras Loss: 0.5119 Train acc:  0.9675,
#  Val Cross loss: 0.0934, Val Contras loss: 0.5477, Val accuracy: 0.9654, Sensitivity: 0.9918, Specificity: 0.9382
#
# Fold [2/10] Epoch [8/30], time cost: 13.3480,
#  Train Cross Loss: 0.0840, Train Contras Loss: 0.4779 Train acc:  0.9719,
#  Val Cross loss: 0.0872, Val Contras loss: 0.4985, Val accuracy: 0.9665, Sensitivity: 0.9844, Specificity: 0.9481
#
# Fold [2/10] Epoch [9/30], time cost: 13.1498,
#  Train Cross Loss: 0.0870, Train Contras Loss: 0.4789 Train acc:  0.9718,
#  Val Cross loss: 0.0948, Val Contras loss: 0.5464, Val accuracy: 0.9672, Sensitivity: 0.9897, Specificity: 0.9440
#
# Fold [2/10] Epoch [10/30], time cost: 13.2576,
#  Train Cross Loss: 0.0851, Train Contras Loss: 0.4646 Train acc:  0.9728,
#  Val Cross loss: 0.1056, Val Contras loss: 0.6029, Val accuracy: 0.9631, Sensitivity: 0.9638, Specificity: 0.9623
#
# Fold [2/10] Epoch [11/30], time cost: 13.2560,
#  Train Cross Loss: 0.0770, Train Contras Loss: 0.4108 Train acc:  0.9744,
#  Val Cross loss: 0.0737, Val Contras loss: 0.3985, Val accuracy: 0.9746, Sensitivity: 0.9798, Specificity: 0.9693
#
# Fold [2/10] Epoch [12/30], time cost: 13.1545,
#  Train Cross Loss: 0.0744, Train Contras Loss: 0.4051 Train acc:  0.9755,
#  Val Cross loss: 0.0766, Val Contras loss: 0.4136, Val accuracy: 0.9730, Sensitivity: 0.9879, Specificity: 0.9576
#
# Fold [2/10] Epoch [13/30], time cost: 13.2180,
#  Train Cross Loss: 0.0637, Train Contras Loss: 0.3356 Train acc:  0.9782,
#  Val Cross loss: 0.1043, Val Contras loss: 0.5696, Val accuracy: 0.9672, Sensitivity: 0.9833, Specificity: 0.9506
#
# Fold [2/10] Epoch [14/30], time cost: 13.3486,
#  Train Cross Loss: 0.0731, Train Contras Loss: 0.3773 Train acc:  0.9760,
#  Val Cross loss: 0.0772, Val Contras loss: 0.4436, Val accuracy: 0.9737, Sensitivity: 0.9904, Specificity: 0.9565
#
# Fold [2/10] Epoch [15/30], time cost: 13.2486,
#  Train Cross Loss: 0.0636, Train Contras Loss: 0.3388 Train acc:  0.9787,
#  Val Cross loss: 0.1062, Val Contras loss: 0.5285, Val accuracy: 0.9685, Sensitivity: 0.9783, Specificity: 0.9583
#
# Fold [2/10] Epoch [16/30], time cost: 13.2917,
#  Train Cross Loss: 0.0614, Train Contras Loss: 0.3267 Train acc:  0.9797,
#  Val Cross loss: 0.0645, Val Contras loss: 0.3607, Val accuracy: 0.9757, Sensitivity: 0.9940, Specificity: 0.9568
#
# Fold [2/10] Epoch [17/30], time cost: 13.2473,
#  Train Cross Loss: 0.0650, Train Contras Loss: 0.3411 Train acc:  0.9776,
#  Val Cross loss: 0.0680, Val Contras loss: 0.3727, Val accuracy: 0.9751, Sensitivity: 0.9925, Specificity: 0.9572
#
# Fold [2/10] Epoch [18/30], time cost: 13.1666,
#  Train Cross Loss: 0.0578, Train Contras Loss: 0.2908 Train acc:  0.9813,
#  Val Cross loss: 0.1153, Val Contras loss: 0.5346, Val accuracy: 0.9699, Sensitivity: 0.9869, Specificity: 0.9525
#
# Fold [2/10] Epoch [19/30], time cost: 13.2775,
#  Train Cross Loss: 0.0549, Train Contras Loss: 0.2875 Train acc:  0.9818,
#  Val Cross loss: 0.0890, Val Contras loss: 0.4015, Val accuracy: 0.9724, Sensitivity: 0.9673, Specificity: 0.9777
#
# Fold [2/10] Epoch [20/30], time cost: 13.5488,
#  Train Cross Loss: 0.0597, Train Contras Loss: 0.3050 Train acc:  0.9813,
#  Val Cross loss: 0.1097, Val Contras loss: 0.6359, Val accuracy: 0.9602, Sensitivity: 0.9908, Specificity: 0.9287
#
# Fold [2/10] Epoch [21/30], time cost: 14.3985,
#  Train Cross Loss: 0.0572, Train Contras Loss: 0.2991 Train acc:  0.9809,
#  Val Cross loss: 0.0720, Val Contras loss: 0.3804, Val accuracy: 0.9737, Sensitivity: 0.9862, Specificity: 0.9609
#
# Fold [2/10] Epoch [22/30], time cost: 13.4062,
#  Train Cross Loss: 0.0500, Train Contras Loss: 0.2548 Train acc:  0.9826,
#  Val Cross loss: 0.0601, Val Contras loss: 0.3042, Val accuracy: 0.9804, Sensitivity: 0.9929, Specificity: 0.9674
#
# Fold [2/10] Epoch [23/30], time cost: 13.4887,
#  Train Cross Loss: 0.0531, Train Contras Loss: 0.2689 Train acc:  0.9824,
#  Val Cross loss: 0.0675, Val Contras loss: 0.3693, Val accuracy: 0.9748, Sensitivity: 0.9883, Specificity: 0.9609
#
# Fold [2/10] Epoch [24/30], time cost: 13.6666,
#  Train Cross Loss: 0.0496, Train Contras Loss: 0.2481 Train acc:  0.9835,
#  Val Cross loss: 0.0683, Val Contras loss: 0.3609, Val accuracy: 0.9766, Sensitivity: 0.9862, Specificity: 0.9667
#
# Fold [2/10] Epoch [25/30], time cost: 13.5545,
#  Train Cross Loss: 0.0504, Train Contras Loss: 0.2562 Train acc:  0.9833,
#  Val Cross loss: 0.0936, Val Contras loss: 0.4922, Val accuracy: 0.9699, Sensitivity: 0.9911, Specificity: 0.9481
#
# Fold [2/10] Epoch [26/30], time cost: 13.2315,
#  Train Cross Loss: 0.0439, Train Contras Loss: 0.2170 Train acc:  0.9850,
#  Val Cross loss: 0.0715, Val Contras loss: 0.3347, Val accuracy: 0.9800, Sensitivity: 0.9933, Specificity: 0.9663
#
# Fold [2/10] Epoch [27/30], time cost: 13.5101,
#  Train Cross Loss: 0.0432, Train Contras Loss: 0.2181 Train acc:  0.9858,
#  Val Cross loss: 0.0788, Val Contras loss: 0.3891, Val accuracy: 0.9735, Sensitivity: 0.9791, Specificity: 0.9678
#
# Fold [2/10] Epoch [28/30], time cost: 13.3024,
#  Train Cross Loss: 0.0442, Train Contras Loss: 0.2244 Train acc:  0.9845,
#  Val Cross loss: 0.0595, Val Contras loss: 0.2914, Val accuracy: 0.9804, Sensitivity: 0.9957, Specificity: 0.9645
#
# Fold [2/10] Epoch [29/30], time cost: 13.5020,
#  Train Cross Loss: 0.0461, Train Contras Loss: 0.2337 Train acc:  0.9845,
#  Val Cross loss: 0.0865, Val Contras loss: 0.4851, Val accuracy: 0.9723, Sensitivity: 0.9698, Specificity: 0.9748
#
# Fold [2/10] Epoch [30/30], time cost: 13.4278,
#  Train Cross Loss: 0.0427, Train Contras Loss: 0.2090 Train acc:  0.9858,
#  Val Cross loss: 0.0676, Val Contras loss: 0.3244, Val accuracy: 0.9789, Sensitivity: 0.9929, Specificity: 0.9645
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 21 Acc: 0.9803638983966853 Sensitivity for pre-ictal: 0.9929002484913028 Specificity: 0.9674469641550841
# ***********
#
# Test Loss: 0.0549, Test accuracy: 0.9812, Sensitivity: 0.9922, Specificity: 0.9701
#
# Fold [3/10] Epoch [1/30], time cost: 13.2072,
#  Train Cross Loss: 0.2866, Train Contras Loss: 1.5783 Train acc:  0.8888,
#  Val Cross loss: 0.2185, Val Contras loss: 1.0973, Val accuracy: 0.9375, Sensitivity: 0.9917, Specificity: 0.8832
#
# Fold [3/10] Epoch [2/30], time cost: 13.4058,
#  Train Cross Loss: 0.1581, Train Contras Loss: 0.8905 Train acc:  0.9497,
#  Val Cross loss: 0.1343, Val Contras loss: 0.7620, Val accuracy: 0.9571, Sensitivity: 0.9856, Specificity: 0.9286
#
# Fold [3/10] Epoch [3/30], time cost: 13.7124,
#  Train Cross Loss: 0.1404, Train Contras Loss: 0.8055 Train acc:  0.9521,
#  Val Cross loss: 0.1184, Val Contras loss: 0.6693, Val accuracy: 0.9696, Sensitivity: 0.9888, Specificity: 0.9503
#
# Fold [3/10] Epoch [4/30], time cost: 13.3381,
#  Train Cross Loss: 0.1253, Train Contras Loss: 0.7112 Train acc:  0.9589,
#  Val Cross loss: 0.1128, Val Contras loss: 0.6411, Val accuracy: 0.9658, Sensitivity: 0.9806, Specificity: 0.9510
#
# Fold [3/10] Epoch [5/30], time cost: 13.4085,
#  Train Cross Loss: 0.1138, Train Contras Loss: 0.6420 Train acc:  0.9633,
#  Val Cross loss: 0.0975, Val Contras loss: 0.5032, Val accuracy: 0.9735, Sensitivity: 0.9827, Specificity: 0.9643
#
# Fold [3/10] Epoch [6/30], time cost: 13.2477,
#  Train Cross Loss: 0.1084, Train Contras Loss: 0.5911 Train acc:  0.9647,
#  Val Cross loss: 0.1329, Val Contras loss: 0.7902, Val accuracy: 0.9535, Sensitivity: 0.9946, Specificity: 0.9124
#
# Fold [3/10] Epoch [7/30], time cost: 13.4249,
#  Train Cross Loss: 0.1029, Train Contras Loss: 0.5764 Train acc:  0.9664,
#  Val Cross loss: 0.1155, Val Contras loss: 0.6001, Val accuracy: 0.9685, Sensitivity: 0.9831, Specificity: 0.9539
#
# Fold [3/10] Epoch [8/30], time cost: 13.2877,
#  Train Cross Loss: 0.0984, Train Contras Loss: 0.5464 Train acc:  0.9673,
#  Val Cross loss: 0.0996, Val Contras loss: 0.5236, Val accuracy: 0.9690, Sensitivity: 0.9917, Specificity: 0.9463
#
# Fold [3/10] Epoch [9/30], time cost: 13.4101,
#  Train Cross Loss: 0.0900, Train Contras Loss: 0.4890 Train acc:  0.9707,
#  Val Cross loss: 0.0898, Val Contras loss: 0.4764, Val accuracy: 0.9683, Sensitivity: 0.9960, Specificity: 0.9405
#
# Fold [3/10] Epoch [10/30], time cost: 13.1729,
#  Train Cross Loss: 0.0928, Train Contras Loss: 0.4898 Train acc:  0.9699,
#  Val Cross loss: 0.1098, Val Contras loss: 0.5449, Val accuracy: 0.9660, Sensitivity: 0.9647, Specificity: 0.9672
#
# Fold [3/10] Epoch [11/30], time cost: 13.3245,
#  Train Cross Loss: 0.0830, Train Contras Loss: 0.4341 Train acc:  0.9731,
#  Val Cross loss: 0.0898, Val Contras loss: 0.4863, Val accuracy: 0.9701, Sensitivity: 0.9852, Specificity: 0.9549
#
# Fold [3/10] Epoch [12/30], time cost: 13.5140,
#  Train Cross Loss: 0.0794, Train Contras Loss: 0.4258 Train acc:  0.9736,
#  Val Cross loss: 0.0866, Val Contras loss: 0.4465, Val accuracy: 0.9733, Sensitivity: 0.9834, Specificity: 0.9632
#
# Fold [3/10] Epoch [13/30], time cost: 13.3376,
#  Train Cross Loss: 0.0784, Train Contras Loss: 0.4169 Train acc:  0.9746,
#  Val Cross loss: 0.0707, Val Contras loss: 0.3414, Val accuracy: 0.9769, Sensitivity: 0.9759, Specificity: 0.9780
#
# Fold [3/10] Epoch [14/30], time cost: 13.2209,
#  Train Cross Loss: 0.0741, Train Contras Loss: 0.3870 Train acc:  0.9757,
#  Val Cross loss: 0.0750, Val Contras loss: 0.4204, Val accuracy: 0.9751, Sensitivity: 0.9845, Specificity: 0.9658
#
# Fold [3/10] Epoch [15/30], time cost: 13.4638,
#  Train Cross Loss: 0.0706, Train Contras Loss: 0.3764 Train acc:  0.9772,
#  Val Cross loss: 0.0863, Val Contras loss: 0.4697, Val accuracy: 0.9742, Sensitivity: 0.9834, Specificity: 0.9650
#
# Fold [3/10] Epoch [16/30], time cost: 13.3662,
#  Train Cross Loss: 0.0704, Train Contras Loss: 0.3574 Train acc:  0.9772,
#  Val Cross loss: 0.0833, Val Contras loss: 0.4227, Val accuracy: 0.9742, Sensitivity: 0.9698, Specificity: 0.9787
#
# Fold [3/10] Epoch [17/30], time cost: 13.2832,
#  Train Cross Loss: 0.0689, Train Contras Loss: 0.3476 Train acc:  0.9782,
#  Val Cross loss: 0.0752, Val Contras loss: 0.4081, Val accuracy: 0.9728, Sensitivity: 0.9921, Specificity: 0.9535
#
# Fold [3/10] Epoch [18/30], time cost: 13.2220,
#  Train Cross Loss: 0.0677, Train Contras Loss: 0.3605 Train acc:  0.9781,
#  Val Cross loss: 0.0850, Val Contras loss: 0.4570, Val accuracy: 0.9703, Sensitivity: 0.9888, Specificity: 0.9517
#
# Fold [3/10] Epoch [19/30], time cost: 13.7002,
#  Train Cross Loss: 0.0641, Train Contras Loss: 0.3254 Train acc:  0.9793,
#  Val Cross loss: 0.0662, Val Contras loss: 0.3448, Val accuracy: 0.9782, Sensitivity: 0.9824, Specificity: 0.9740
#
# Fold [3/10] Epoch [20/30], time cost: 13.2584,
#  Train Cross Loss: 0.0605, Train Contras Loss: 0.3059 Train acc:  0.9798,
#  Val Cross loss: 0.0724, Val Contras loss: 0.4110, Val accuracy: 0.9769, Sensitivity: 0.9856, Specificity: 0.9683
#
# Fold [3/10] Epoch [21/30], time cost: 13.3782,
#  Train Cross Loss: 0.0537, Train Contras Loss: 0.2699 Train acc:  0.9814,
#  Val Cross loss: 0.1031, Val Contras loss: 0.5235, Val accuracy: 0.9678, Sensitivity: 0.9816, Specificity: 0.9539
#
# Fold [3/10] Epoch [22/30], time cost: 13.2294,
#  Train Cross Loss: 0.0579, Train Contras Loss: 0.2883 Train acc:  0.9812,
#  Val Cross loss: 0.0673, Val Contras loss: 0.3470, Val accuracy: 0.9762, Sensitivity: 0.9881, Specificity: 0.9643
#
# Fold [3/10] Epoch [23/30], time cost: 13.9796,
#  Train Cross Loss: 0.0574, Train Contras Loss: 0.2850 Train acc:  0.9811,
#  Val Cross loss: 0.0850, Val Contras loss: 0.4292, Val accuracy: 0.9742, Sensitivity: 0.9759, Specificity: 0.9726
#
# Fold [3/10] Epoch [24/30], time cost: 14.0539,
#  Train Cross Loss: 0.0551, Train Contras Loss: 0.2670 Train acc:  0.9825,
#  Val Cross loss: 0.0788, Val Contras loss: 0.3837, Val accuracy: 0.9746, Sensitivity: 0.9910, Specificity: 0.9582
#
# Fold [3/10] Epoch [25/30], time cost: 14.0089,
#  Train Cross Loss: 0.0534, Train Contras Loss: 0.2626 Train acc:  0.9827,
#  Val Cross loss: 0.0665, Val Contras loss: 0.3441, Val accuracy: 0.9782, Sensitivity: 0.9957, Specificity: 0.9607
#
# Fold [3/10] Epoch [26/30], time cost: 14.0757,
#  Train Cross Loss: 0.0601, Train Contras Loss: 0.2991 Train acc:  0.9800,
#  Val Cross loss: 0.0745, Val Contras loss: 0.3556, Val accuracy: 0.9773, Sensitivity: 0.9831, Specificity: 0.9715
#
# Fold [3/10] Epoch [27/30], time cost: 13.9389,
#  Train Cross Loss: 0.0557, Train Contras Loss: 0.2849 Train acc:  0.9810,
#  Val Cross loss: 0.0633, Val Contras loss: 0.3159, Val accuracy: 0.9787, Sensitivity: 0.9917, Specificity: 0.9658
#
# Fold [3/10] Epoch [28/30], time cost: 13.5757,
#  Train Cross Loss: 0.0483, Train Contras Loss: 0.2392 Train acc:  0.9838,
#  Val Cross loss: 0.0654, Val Contras loss: 0.3154, Val accuracy: 0.9787, Sensitivity: 0.9849, Specificity: 0.9726
#
# Fold [3/10] Epoch [29/30], time cost: 13.3990,
#  Train Cross Loss: 0.0541, Train Contras Loss: 0.2711 Train acc:  0.9825,
#  Val Cross loss: 0.0720, Val Contras loss: 0.3492, Val accuracy: 0.9775, Sensitivity: 0.9910, Specificity: 0.9640
#
# Fold [3/10] Epoch [30/30], time cost: 13.3460,
#  Train Cross Loss: 0.0562, Train Contras Loss: 0.2792 Train acc:  0.9815,
#  Val Cross loss: 0.0798, Val Contras loss: 0.3675, Val accuracy: 0.9766, Sensitivity: 0.9888, Specificity: 0.9643
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 26 Acc: 0.9787425689065034 Sensitivity for pre-ictal: 0.9917176809506661 Specificity: 0.9657534246575342
# ***********
#
# Test Loss: 0.0695, Test accuracy: 0.9750, Sensitivity: 0.9935, Specificity: 0.9565
#
# Fold [4/10] Epoch [1/30], time cost: 13.1587,
#  Train Cross Loss: 0.2523, Train Contras Loss: 1.3664 Train acc:  0.9050,
#  Val Cross loss: 0.1369, Val Contras loss: 0.8101, Val accuracy: 0.9523, Sensitivity: 0.9876, Specificity: 0.9175
#
# Fold [4/10] Epoch [2/30], time cost: 13.4281,
#  Train Cross Loss: 0.1455, Train Contras Loss: 0.8352 Train acc:  0.9525,
#  Val Cross loss: 0.1398, Val Contras loss: 0.7307, Val accuracy: 0.9571, Sensitivity: 0.9927, Specificity: 0.9221
#
# Fold [4/10] Epoch [3/30], time cost: 13.2545,
#  Train Cross Loss: 0.1190, Train Contras Loss: 0.6800 Train acc:  0.9610,
#  Val Cross loss: 0.1119, Val Contras loss: 0.5804, Val accuracy: 0.9678, Sensitivity: 0.9720, Specificity: 0.9636
#
# Fold [4/10] Epoch [4/30], time cost: 13.2080,
#  Train Cross Loss: 0.1131, Train Contras Loss: 0.6291 Train acc:  0.9629,
#  Val Cross loss: 0.1002, Val Contras loss: 0.5799, Val accuracy: 0.9658, Sensitivity: 0.9789, Specificity: 0.9529
#
# Fold [4/10] Epoch [5/30], time cost: 13.0963,
#  Train Cross Loss: 0.1050, Train Contras Loss: 0.5746 Train acc:  0.9667,
#  Val Cross loss: 0.0948, Val Contras loss: 0.5175, Val accuracy: 0.9669, Sensitivity: 0.9920, Specificity: 0.9421
#
# Fold [4/10] Epoch [6/30], time cost: 13.1761,
#  Train Cross Loss: 0.0955, Train Contras Loss: 0.5182 Train acc:  0.9680,
#  Val Cross loss: 0.1035, Val Contras loss: 0.5465, Val accuracy: 0.9658, Sensitivity: 0.9938, Specificity: 0.9382
#
# Fold [4/10] Epoch [7/30], time cost: 13.2535,
#  Train Cross Loss: 0.0889, Train Contras Loss: 0.4937 Train acc:  0.9703,
#  Val Cross loss: 0.1278, Val Contras loss: 0.6429, Val accuracy: 0.9618, Sensitivity: 0.9884, Specificity: 0.9357
#
# Fold [4/10] Epoch [8/30], time cost: 13.5199,
#  Train Cross Loss: 0.0897, Train Contras Loss: 0.4801 Train acc:  0.9709,
#  Val Cross loss: 0.1110, Val Contras loss: 0.5618, Val accuracy: 0.9692, Sensitivity: 0.9793, Specificity: 0.9593
#
# Fold [4/10] Epoch [9/30], time cost: 13.5103,
#  Train Cross Loss: 0.0807, Train Contras Loss: 0.4381 Train acc:  0.9721,
#  Val Cross loss: 0.0764, Val Contras loss: 0.4107, Val accuracy: 0.9732, Sensitivity: 0.9793, Specificity: 0.9671
#
# Fold [4/10] Epoch [10/30], time cost: 13.4306,
#  Train Cross Loss: 0.0824, Train Contras Loss: 0.4512 Train acc:  0.9724,
#  Val Cross loss: 0.0935, Val Contras loss: 0.5076, Val accuracy: 0.9678, Sensitivity: 0.9920, Specificity: 0.9439
#
# Fold [4/10] Epoch [11/30], time cost: 13.2061,
#  Train Cross Loss: 0.0746, Train Contras Loss: 0.4022 Train acc:  0.9739,
#  Val Cross loss: 0.0752, Val Contras loss: 0.4107, Val accuracy: 0.9735, Sensitivity: 0.9862, Specificity: 0.9611
#
# Fold [4/10] Epoch [12/30], time cost: 13.3561,
#  Train Cross Loss: 0.0699, Train Contras Loss: 0.3670 Train acc:  0.9773,
#  Val Cross loss: 0.0811, Val Contras loss: 0.3994, Val accuracy: 0.9773, Sensitivity: 0.9880, Specificity: 0.9668
#
# Fold [4/10] Epoch [13/30], time cost: 14.5597,
#  Train Cross Loss: 0.0735, Train Contras Loss: 0.3950 Train acc:  0.9753,
#  Val Cross loss: 0.0723, Val Contras loss: 0.3844, Val accuracy: 0.9742, Sensitivity: 0.9938, Specificity: 0.9550
#
# Fold [4/10] Epoch [14/30], time cost: 15.9605,
#  Train Cross Loss: 0.0636, Train Contras Loss: 0.3239 Train acc:  0.9786,
#  Val Cross loss: 0.0785, Val Contras loss: 0.4413, Val accuracy: 0.9683, Sensitivity: 0.9655, Specificity: 0.9711
#
# Fold [4/10] Epoch [15/30], time cost: 15.7323,
#  Train Cross Loss: 0.0642, Train Contras Loss: 0.3418 Train acc:  0.9785,
#  Val Cross loss: 0.0808, Val Contras loss: 0.4792, Val accuracy: 0.9685, Sensitivity: 0.9644, Specificity: 0.9725
#
# Fold [4/10] Epoch [16/30], time cost: 14.4117,
#  Train Cross Loss: 0.0633, Train Contras Loss: 0.3295 Train acc:  0.9788,
#  Val Cross loss: 0.0564, Val Contras loss: 0.3053, Val accuracy: 0.9796, Sensitivity: 0.9913, Specificity: 0.9682
#
# Fold [4/10] Epoch [17/30], time cost: 13.8699,
#  Train Cross Loss: 0.0627, Train Contras Loss: 0.3177 Train acc:  0.9783,
#  Val Cross loss: 0.0673, Val Contras loss: 0.3598, Val accuracy: 0.9775, Sensitivity: 0.9898, Specificity: 0.9654
#
# Fold [4/10] Epoch [18/30], time cost: 14.0111,
#  Train Cross Loss: 0.0572, Train Contras Loss: 0.2886 Train acc:  0.9810,
#  Val Cross loss: 0.0578, Val Contras loss: 0.3203, Val accuracy: 0.9766, Sensitivity: 0.9924, Specificity: 0.9611
#
# Fold [4/10] Epoch [19/30], time cost: 14.3998,
#  Train Cross Loss: 0.0590, Train Contras Loss: 0.2955 Train acc:  0.9811,
#  Val Cross loss: 0.0639, Val Contras loss: 0.3265, Val accuracy: 0.9780, Sensitivity: 0.9975, Specificity: 0.9589
#
# Fold [4/10] Epoch [20/30], time cost: 15.8962,
#  Train Cross Loss: 0.0574, Train Contras Loss: 0.2954 Train acc:  0.9810,
#  Val Cross loss: 0.0579, Val Contras loss: 0.2902, Val accuracy: 0.9811, Sensitivity: 0.9935, Specificity: 0.9689
#
# Fold [4/10] Epoch [21/30], time cost: 15.9593,
#  Train Cross Loss: 0.0571, Train Contras Loss: 0.2892 Train acc:  0.9814,
#  Val Cross loss: 0.0811, Val Contras loss: 0.3850, Val accuracy: 0.9726, Sensitivity: 0.9982, Specificity: 0.9475
#
# Fold [4/10] Epoch [22/30], time cost: 15.8386,
#  Train Cross Loss: 0.0543, Train Contras Loss: 0.2672 Train acc:  0.9824,
#  Val Cross loss: 0.0657, Val Contras loss: 0.3411, Val accuracy: 0.9782, Sensitivity: 0.9895, Specificity: 0.9671
#
# Fold [4/10] Epoch [23/30], time cost: 15.8242,
#  Train Cross Loss: 0.0490, Train Contras Loss: 0.2472 Train acc:  0.9837,
#  Val Cross loss: 0.0575, Val Contras loss: 0.3086, Val accuracy: 0.9818, Sensitivity: 0.9898, Specificity: 0.9739
#
# Fold [4/10] Epoch [24/30], time cost: 16.0042,
#  Train Cross Loss: 0.0499, Train Contras Loss: 0.2548 Train acc:  0.9830,
#  Val Cross loss: 0.0635, Val Contras loss: 0.3178, Val accuracy: 0.9800, Sensitivity: 0.9818, Specificity: 0.9782
#
# Fold [4/10] Epoch [25/30], time cost: 15.8994,
#  Train Cross Loss: 0.0547, Train Contras Loss: 0.2712 Train acc:  0.9817,
#  Val Cross loss: 0.0674, Val Contras loss: 0.3540, Val accuracy: 0.9741, Sensitivity: 0.9807, Specificity: 0.9675
#
# Fold [4/10] Epoch [26/30], time cost: 16.1316,
#  Train Cross Loss: 0.0499, Train Contras Loss: 0.2490 Train acc:  0.9836,
#  Val Cross loss: 0.0545, Val Contras loss: 0.2734, Val accuracy: 0.9823, Sensitivity: 0.9902, Specificity: 0.9746
#
# Fold [4/10] Epoch [27/30], time cost: 15.9983,
#  Train Cross Loss: 0.0497, Train Contras Loss: 0.2443 Train acc:  0.9837,
#  Val Cross loss: 0.0630, Val Contras loss: 0.3376, Val accuracy: 0.9787, Sensitivity: 0.9764, Specificity: 0.9811
#
# Fold [4/10] Epoch [28/30], time cost: 15.5945,
#  Train Cross Loss: 0.0457, Train Contras Loss: 0.2335 Train acc:  0.9844,
#  Val Cross loss: 0.0542, Val Contras loss: 0.2628, Val accuracy: 0.9838, Sensitivity: 0.9895, Specificity: 0.9782
#
# Fold [4/10] Epoch [29/30], time cost: 15.3056,
#  Train Cross Loss: 0.0491, Train Contras Loss: 0.2329 Train acc:  0.9841,
#  Val Cross loss: 0.0516, Val Contras loss: 0.2525, Val accuracy: 0.9834, Sensitivity: 0.9920, Specificity: 0.9750
#
# Fold [4/10] Epoch [30/30], time cost: 14.2859,
#  Train Cross Loss: 0.0548, Train Contras Loss: 0.2584 Train acc:  0.9847,
#  Val Cross loss: 0.0598, Val Contras loss: 0.2926, Val accuracy: 0.9813, Sensitivity: 0.9956, Specificity: 0.9671
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 27 Acc: 0.9837867050981806 Sensitivity for pre-ictal: 0.9894583787713559 Specificity: 0.9782142857142857
# ***********
#
# Test Loss: 0.0674, Test accuracy: 0.9773, Sensitivity: 0.9858, Specificity: 0.9688
#
# Fold [5/10] Epoch [1/30], time cost: 16.0777,
#  Train Cross Loss: 0.2912, Train Contras Loss: 1.5685 Train acc:  0.8890,
#  Val Cross loss: 0.1936, Val Contras loss: 1.0397, Val accuracy: 0.9229, Sensitivity: 0.9770, Specificity: 0.8683
#
# Fold [5/10] Epoch [2/30], time cost: 16.1113,
#  Train Cross Loss: 0.1518, Train Contras Loss: 0.8755 Train acc:  0.9469,
#  Val Cross loss: 0.1162, Val Contras loss: 0.6235, Val accuracy: 0.9613, Sensitivity: 0.9742, Specificity: 0.9483
#
# Fold [5/10] Epoch [3/30], time cost: 15.9086,
#  Train Cross Loss: 0.1214, Train Contras Loss: 0.6876 Train acc:  0.9592,
#  Val Cross loss: 0.1042, Val Contras loss: 0.6196, Val accuracy: 0.9620, Sensitivity: 0.9900, Specificity: 0.9338
#
# Fold [5/10] Epoch [4/30], time cost: 15.6998,
#  Train Cross Loss: 0.1117, Train Contras Loss: 0.6269 Train acc:  0.9637,
#  Val Cross loss: 0.0915, Val Contras loss: 0.5366, Val accuracy: 0.9667, Sensitivity: 0.9864, Specificity: 0.9468
#
# Fold [5/10] Epoch [5/30], time cost: 15.7409,
#  Train Cross Loss: 0.1058, Train Contras Loss: 0.5773 Train acc:  0.9653,
#  Val Cross loss: 0.1032, Val Contras loss: 0.5779, Val accuracy: 0.9665, Sensitivity: 0.9824, Specificity: 0.9504
#
# Fold [5/10] Epoch [6/30], time cost: 15.8338,
#  Train Cross Loss: 0.0982, Train Contras Loss: 0.5292 Train acc:  0.9682,
#  Val Cross loss: 0.1027, Val Contras loss: 0.5745, Val accuracy: 0.9683, Sensitivity: 0.9917, Specificity: 0.9446
#
# Fold [5/10] Epoch [7/30], time cost: 15.8540,
#  Train Cross Loss: 0.0932, Train Contras Loss: 0.5038 Train acc:  0.9693,
#  Val Cross loss: 0.1116, Val Contras loss: 0.6203, Val accuracy: 0.9663, Sensitivity: 0.9885, Specificity: 0.9439
#
# Fold [5/10] Epoch [8/30], time cost: 16.0106,
#  Train Cross Loss: 0.0883, Train Contras Loss: 0.4746 Train acc:  0.9706,
#  Val Cross loss: 0.0889, Val Contras loss: 0.4913, Val accuracy: 0.9708, Sensitivity: 0.9842, Specificity: 0.9573
#
# Fold [5/10] Epoch [9/30], time cost: 16.0233,
#  Train Cross Loss: 0.0830, Train Contras Loss: 0.4328 Train acc:  0.9730,
#  Val Cross loss: 0.0737, Val Contras loss: 0.3726, Val accuracy: 0.9755, Sensitivity: 0.9828, Specificity: 0.9682
#
# Fold [5/10] Epoch [10/30], time cost: 15.8796,
#  Train Cross Loss: 0.0794, Train Contras Loss: 0.4284 Train acc:  0.9741,
#  Val Cross loss: 0.0760, Val Contras loss: 0.4006, Val accuracy: 0.9748, Sensitivity: 0.9842, Specificity: 0.9653
#
# Fold [5/10] Epoch [11/30], time cost: 15.9986,
#  Train Cross Loss: 0.0803, Train Contras Loss: 0.4075 Train acc:  0.9745,
#  Val Cross loss: 0.0787, Val Contras loss: 0.3957, Val accuracy: 0.9742, Sensitivity: 0.9943, Specificity: 0.9541
#
# Fold [5/10] Epoch [12/30], time cost: 15.8930,
#  Train Cross Loss: 0.0736, Train Contras Loss: 0.3803 Train acc:  0.9759,
#  Val Cross loss: 0.0682, Val Contras loss: 0.3641, Val accuracy: 0.9766, Sensitivity: 0.9903, Specificity: 0.9627
#
# Fold [5/10] Epoch [13/30], time cost: 15.8317,
#  Train Cross Loss: 0.0711, Train Contras Loss: 0.3755 Train acc:  0.9762,
#  Val Cross loss: 0.0681, Val Contras loss: 0.3596, Val accuracy: 0.9798, Sensitivity: 0.9900, Specificity: 0.9696
#
# Fold [5/10] Epoch [14/30], time cost: 15.8981,
#  Train Cross Loss: 0.0686, Train Contras Loss: 0.3607 Train acc:  0.9777,
#  Val Cross loss: 0.0698, Val Contras loss: 0.3720, Val accuracy: 0.9766, Sensitivity: 0.9792, Specificity: 0.9740
#
# Fold [5/10] Epoch [15/30], time cost: 15.8475,
#  Train Cross Loss: 0.0705, Train Contras Loss: 0.3561 Train acc:  0.9778,
#  Val Cross loss: 0.0647, Val Contras loss: 0.3547, Val accuracy: 0.9780, Sensitivity: 0.9824, Specificity: 0.9736
#
# Fold [5/10] Epoch [16/30], time cost: 15.9338,
#  Train Cross Loss: 0.0679, Train Contras Loss: 0.3526 Train acc:  0.9786,
#  Val Cross loss: 0.0639, Val Contras loss: 0.2991, Val accuracy: 0.9796, Sensitivity: 0.9882, Specificity: 0.9711
#
# Fold [5/10] Epoch [17/30], time cost: 15.8827,
#  Train Cross Loss: 0.0616, Train Contras Loss: 0.3181 Train acc:  0.9804,
#  Val Cross loss: 0.0801, Val Contras loss: 0.3972, Val accuracy: 0.9789, Sensitivity: 0.9867, Specificity: 0.9711
#
# Fold [5/10] Epoch [18/30], time cost: 15.7816,
#  Train Cross Loss: 0.0602, Train Contras Loss: 0.3137 Train acc:  0.9807,
#  Val Cross loss: 0.0697, Val Contras loss: 0.3652, Val accuracy: 0.9759, Sensitivity: 0.9839, Specificity: 0.9678
#
# Fold [5/10] Epoch [19/30], time cost: 15.8457,
#  Train Cross Loss: 0.0600, Train Contras Loss: 0.3033 Train acc:  0.9808,
#  Val Cross loss: 0.0661, Val Contras loss: 0.3753, Val accuracy: 0.9750, Sensitivity: 0.9842, Specificity: 0.9656
#
# Fold [5/10] Epoch [20/30], time cost: 15.9096,
#  Train Cross Loss: 0.0618, Train Contras Loss: 0.3115 Train acc:  0.9796,
#  Val Cross loss: 0.0643, Val Contras loss: 0.3478, Val accuracy: 0.9798, Sensitivity: 0.9878, Specificity: 0.9718
#
# Fold [5/10] Epoch [21/30], time cost: 15.8604,
#  Train Cross Loss: 0.0588, Train Contras Loss: 0.2922 Train acc:  0.9815,
#  Val Cross loss: 0.0621, Val Contras loss: 0.3286, Val accuracy: 0.9786, Sensitivity: 0.9914, Specificity: 0.9656
#
# Fold [5/10] Epoch [22/30], time cost: 16.0332,
#  Train Cross Loss: 0.0617, Train Contras Loss: 0.3074 Train acc:  0.9805,
#  Val Cross loss: 0.0669, Val Contras loss: 0.3513, Val accuracy: 0.9744, Sensitivity: 0.9738, Specificity: 0.9750
#
# Fold [5/10] Epoch [23/30], time cost: 15.8844,
#  Train Cross Loss: 0.0534, Train Contras Loss: 0.2663 Train acc:  0.9823,
#  Val Cross loss: 0.0493, Val Contras loss: 0.2551, Val accuracy: 0.9841, Sensitivity: 0.9950, Specificity: 0.9732
#
# Fold [5/10] Epoch [24/30], time cost: 15.8438,
#  Train Cross Loss: 0.0552, Train Contras Loss: 0.2821 Train acc:  0.9813,
#  Val Cross loss: 0.0617, Val Contras loss: 0.3072, Val accuracy: 0.9800, Sensitivity: 0.9914, Specificity: 0.9685
#
# Fold [5/10] Epoch [25/30], time cost: 15.7889,
#  Train Cross Loss: 0.0518, Train Contras Loss: 0.2664 Train acc:  0.9825,
#  Val Cross loss: 0.0938, Val Contras loss: 0.4527, Val accuracy: 0.9742, Sensitivity: 0.9778, Specificity: 0.9707
#
# Fold [5/10] Epoch [26/30], time cost: 15.7649,
#  Train Cross Loss: 0.0573, Train Contras Loss: 0.2762 Train acc:  0.9818,
#  Val Cross loss: 0.0591, Val Contras loss: 0.3575, Val accuracy: 0.9759, Sensitivity: 0.9921, Specificity: 0.9595
#
# Fold [5/10] Epoch [27/30], time cost: 15.7796,
#  Train Cross Loss: 0.0516, Train Contras Loss: 0.2518 Train acc:  0.9841,
#  Val Cross loss: 0.0660, Val Contras loss: 0.3123, Val accuracy: 0.9822, Sensitivity: 0.9950, Specificity: 0.9692
#
# Fold [5/10] Epoch [28/30], time cost: 15.6674,
#  Train Cross Loss: 0.0479, Train Contras Loss: 0.2443 Train acc:  0.9841,
#  Val Cross loss: 0.0579, Val Contras loss: 0.2908, Val accuracy: 0.9789, Sensitivity: 0.9774, Specificity: 0.9805
#
# Fold [5/10] Epoch [29/30], time cost: 15.5948,
#  Train Cross Loss: 0.0543, Train Contras Loss: 0.2651 Train acc:  0.9831,
#  Val Cross loss: 0.0558, Val Contras loss: 0.2982, Val accuracy: 0.9800, Sensitivity: 0.9910, Specificity: 0.9689
#
# Fold [5/10] Epoch [30/30], time cost: 15.8523,
#  Train Cross Loss: 0.0491, Train Contras Loss: 0.2398 Train acc:  0.9843,
#  Val Cross loss: 0.0571, Val Contras loss: 0.2687, Val accuracy: 0.9823, Sensitivity: 0.9839, Specificity: 0.9808
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 22 Acc: 0.9841470005404431 Sensitivity for pre-ictal: 0.9949766774309293 Specificity: 0.9732272069464544
# ***********
#
# Test Loss: 0.0517, Test accuracy: 0.9812, Sensitivity: 0.9909, Specificity: 0.9714
#
# Fold [6/10] Epoch [1/30], time cost: 15.6986,
#  Train Cross Loss: 0.2511, Train Contras Loss: 1.3682 Train acc:  0.9061,
#  Val Cross loss: 0.1626, Val Contras loss: 0.9523, Val accuracy: 0.9472, Sensitivity: 0.9813, Specificity: 0.9130
#
# Fold [6/10] Epoch [2/30], time cost: 15.8045,
#  Train Cross Loss: 0.1430, Train Contras Loss: 0.8033 Train acc:  0.9550,
#  Val Cross loss: 0.1435, Val Contras loss: 0.8652, Val accuracy: 0.9517, Sensitivity: 0.9738, Specificity: 0.9296
#
# Fold [6/10] Epoch [3/30], time cost: 16.1215,
#  Train Cross Loss: 0.1209, Train Contras Loss: 0.6802 Train acc:  0.9622,
#  Val Cross loss: 0.1088, Val Contras loss: 0.6306, Val accuracy: 0.9661, Sensitivity: 0.9795, Specificity: 0.9527
#
# Fold [6/10] Epoch [4/30], time cost: 15.7716,
#  Train Cross Loss: 0.1060, Train Contras Loss: 0.6007 Train acc:  0.9653,
#  Val Cross loss: 0.0973, Val Contras loss: 0.5361, Val accuracy: 0.9692, Sensitivity: 0.9871, Specificity: 0.9512
#
# Fold [6/10] Epoch [5/30], time cost: 15.8121,
#  Train Cross Loss: 0.0985, Train Contras Loss: 0.5437 Train acc:  0.9688,
#  Val Cross loss: 0.1015, Val Contras loss: 0.6005, Val accuracy: 0.9656, Sensitivity: 0.9770, Specificity: 0.9541
#
# Fold [6/10] Epoch [6/30], time cost: 15.8574,
#  Train Cross Loss: 0.1005, Train Contras Loss: 0.5497 Train acc:  0.9673,
#  Val Cross loss: 0.0819, Val Contras loss: 0.4474, Val accuracy: 0.9735, Sensitivity: 0.9863, Specificity: 0.9606
#
# Fold [6/10] Epoch [7/30], time cost: 15.7422,
#  Train Cross Loss: 0.0915, Train Contras Loss: 0.4900 Train acc:  0.9698,
#  Val Cross loss: 0.0928, Val Contras loss: 0.4863, Val accuracy: 0.9678, Sensitivity: 0.9975, Specificity: 0.9379
#
# Fold [6/10] Epoch [8/30], time cost: 15.8762,
#  Train Cross Loss: 0.0825, Train Contras Loss: 0.4528 Train acc:  0.9716,
#  Val Cross loss: 0.0838, Val Contras loss: 0.4414, Val accuracy: 0.9732, Sensitivity: 0.9770, Specificity: 0.9693
#
# Fold [6/10] Epoch [9/30], time cost: 15.8520,
#  Train Cross Loss: 0.0773, Train Contras Loss: 0.4259 Train acc:  0.9746,
#  Val Cross loss: 0.0962, Val Contras loss: 0.5274, Val accuracy: 0.9669, Sensitivity: 0.9921, Specificity: 0.9415
#
# Fold [6/10] Epoch [10/30], time cost: 15.7950,
#  Train Cross Loss: 0.0776, Train Contras Loss: 0.4119 Train acc:  0.9744,
#  Val Cross loss: 0.0733, Val Contras loss: 0.4018, Val accuracy: 0.9782, Sensitivity: 0.9910, Specificity: 0.9653
#
# Fold [6/10] Epoch [11/30], time cost: 15.9190,
#  Train Cross Loss: 0.0728, Train Contras Loss: 0.3866 Train acc:  0.9770,
#  Val Cross loss: 0.0900, Val Contras loss: 0.5094, Val accuracy: 0.9687, Sensitivity: 0.9874, Specificity: 0.9498
#
# Fold [6/10] Epoch [12/30], time cost: 15.7320,
#  Train Cross Loss: 0.0709, Train Contras Loss: 0.3614 Train acc:  0.9775,
#  Val Cross loss: 0.0837, Val Contras loss: 0.4772, Val accuracy: 0.9742, Sensitivity: 0.9896, Specificity: 0.9588
#
# Fold [6/10] Epoch [13/30], time cost: 15.7599,
#  Train Cross Loss: 0.0713, Train Contras Loss: 0.3783 Train acc:  0.9766,
#  Val Cross loss: 0.0690, Val Contras loss: 0.3668, Val accuracy: 0.9755, Sensitivity: 0.9946, Specificity: 0.9563
#
# Fold [6/10] Epoch [14/30], time cost: 15.7747,
#  Train Cross Loss: 0.0686, Train Contras Loss: 0.3640 Train acc:  0.9776,
#  Val Cross loss: 0.0688, Val Contras loss: 0.3610, Val accuracy: 0.9809, Sensitivity: 0.9939, Specificity: 0.9679
#
# Fold [6/10] Epoch [15/30], time cost: 15.9544,
#  Train Cross Loss: 0.0694, Train Contras Loss: 0.3528 Train acc:  0.9786,
#  Val Cross loss: 0.0968, Val Contras loss: 0.5200, Val accuracy: 0.9690, Sensitivity: 0.9860, Specificity: 0.9520
#
# Fold [6/10] Epoch [16/30], time cost: 15.6627,
#  Train Cross Loss: 0.0673, Train Contras Loss: 0.3580 Train acc:  0.9788,
#  Val Cross loss: 0.0690, Val Contras loss: 0.3729, Val accuracy: 0.9771, Sensitivity: 0.9957, Specificity: 0.9585
#
# Fold [6/10] Epoch [17/30], time cost: 15.8103,
#  Train Cross Loss: 0.0621, Train Contras Loss: 0.3208 Train acc:  0.9794,
#  Val Cross loss: 0.0692, Val Contras loss: 0.3620, Val accuracy: 0.9778, Sensitivity: 0.9953, Specificity: 0.9603
#
# Fold [6/10] Epoch [18/30], time cost: 15.6811,
#  Train Cross Loss: 0.0655, Train Contras Loss: 0.3308 Train acc:  0.9791,
#  Val Cross loss: 0.0842, Val Contras loss: 0.4184, Val accuracy: 0.9746, Sensitivity: 0.9968, Specificity: 0.9523
#
# Fold [6/10] Epoch [19/30], time cost: 15.9276,
#  Train Cross Loss: 0.0581, Train Contras Loss: 0.2983 Train acc:  0.9817,
#  Val Cross loss: 0.0798, Val Contras loss: 0.4336, Val accuracy: 0.9712, Sensitivity: 0.9932, Specificity: 0.9491
#
# Fold [6/10] Epoch [20/30], time cost: 15.8975,
#  Train Cross Loss: 0.0548, Train Contras Loss: 0.2801 Train acc:  0.9821,
#  Val Cross loss: 0.0645, Val Contras loss: 0.3286, Val accuracy: 0.9804, Sensitivity: 0.9892, Specificity: 0.9715
#
# Fold [6/10] Epoch [21/30], time cost: 15.8421,
#  Train Cross Loss: 0.0551, Train Contras Loss: 0.2814 Train acc:  0.9834,
#  Val Cross loss: 0.0789, Val Contras loss: 0.4180, Val accuracy: 0.9728, Sensitivity: 0.9932, Specificity: 0.9523
#
# Fold [6/10] Epoch [22/30], time cost: 15.9796,
#  Train Cross Loss: 0.0596, Train Contras Loss: 0.3097 Train acc:  0.9803,
#  Val Cross loss: 0.0897, Val Contras loss: 0.4185, Val accuracy: 0.9769, Sensitivity: 0.9903, Specificity: 0.9635
#
# Fold [6/10] Epoch [23/30], time cost: 15.8427,
#  Train Cross Loss: 0.0541, Train Contras Loss: 0.2803 Train acc:  0.9825,
#  Val Cross loss: 0.0556, Val Contras loss: 0.2834, Val accuracy: 0.9807, Sensitivity: 0.9917, Specificity: 0.9697
#
# Fold [6/10] Epoch [24/30], time cost: 15.8285,
#  Train Cross Loss: 0.0566, Train Contras Loss: 0.2901 Train acc:  0.9810,
#  Val Cross loss: 0.0603, Val Contras loss: 0.2999, Val accuracy: 0.9787, Sensitivity: 0.9971, Specificity: 0.9603
#
# Fold [6/10] Epoch [25/30], time cost: 15.8106,
#  Train Cross Loss: 0.0492, Train Contras Loss: 0.2412 Train acc:  0.9848,
#  Val Cross loss: 0.0702, Val Contras loss: 0.3795, Val accuracy: 0.9762, Sensitivity: 0.9813, Specificity: 0.9711
#
# Fold [6/10] Epoch [26/30], time cost: 15.6922,
#  Train Cross Loss: 0.0496, Train Contras Loss: 0.2320 Train acc:  0.9844,
#  Val Cross loss: 0.0689, Val Contras loss: 0.3511, Val accuracy: 0.9782, Sensitivity: 0.9849, Specificity: 0.9715
#
# Fold [6/10] Epoch [27/30], time cost: 16.0493,
#  Train Cross Loss: 0.0466, Train Contras Loss: 0.2272 Train acc:  0.9855,
#  Val Cross loss: 0.0634, Val Contras loss: 0.3288, Val accuracy: 0.9760, Sensitivity: 0.9835, Specificity: 0.9686
#
# Fold [6/10] Epoch [28/30], time cost: 15.7803,
#  Train Cross Loss: 0.0467, Train Contras Loss: 0.2324 Train acc:  0.9842,
#  Val Cross loss: 0.0751, Val Contras loss: 0.3836, Val accuracy: 0.9762, Sensitivity: 0.9917, Specificity: 0.9606
#
# Fold [6/10] Epoch [29/30], time cost: 15.6660,
#  Train Cross Loss: 0.0534, Train Contras Loss: 0.2693 Train acc:  0.9831,
#  Val Cross loss: 0.0635, Val Contras loss: 0.3158, Val accuracy: 0.9805, Sensitivity: 0.9928, Specificity: 0.9682
#
# Fold [6/10] Epoch [30/30], time cost: 15.6136,
#  Train Cross Loss: 0.0455, Train Contras Loss: 0.2288 Train acc:  0.9851,
#  Val Cross loss: 0.0586, Val Contras loss: 0.2994, Val accuracy: 0.9814, Sensitivity: 0.9874, Specificity: 0.9754
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 29 Acc: 0.9814447847234733 Sensitivity for pre-ictal: 0.9874191229331416 Specificity: 0.9754423979776092
# ***********
#
# Test Loss: 0.0508, Test accuracy: 0.9835, Sensitivity: 0.9884, Specificity: 0.9785
#
# Fold [7/10] Epoch [1/30], time cost: 15.7943,
#  Train Cross Loss: 0.2744, Train Contras Loss: 1.4901 Train acc:  0.8935,
#  Val Cross loss: 0.1661, Val Contras loss: 0.8846, Val accuracy: 0.9479, Sensitivity: 0.9837, Specificity: 0.9126
#
# Fold [7/10] Epoch [2/30], time cost: 15.8316,
#  Train Cross Loss: 0.1470, Train Contras Loss: 0.8378 Train acc:  0.9539,
#  Val Cross loss: 0.1599, Val Contras loss: 0.9166, Val accuracy: 0.9431, Sensitivity: 0.9428, Specificity: 0.9434
#
# Fold [7/10] Epoch [3/30], time cost: 15.8396,
#  Train Cross Loss: 0.1256, Train Contras Loss: 0.7213 Train acc:  0.9598,
#  Val Cross loss: 0.1266, Val Contras loss: 0.7069, Val accuracy: 0.9614, Sensitivity: 0.9623, Specificity: 0.9606
#
# Fold [7/10] Epoch [4/30], time cost: 15.6314,
#  Train Cross Loss: 0.1133, Train Contras Loss: 0.6469 Train acc:  0.9628,
#  Val Cross loss: 0.1460, Val Contras loss: 0.6832, Val accuracy: 0.9620, Sensitivity: 0.9830, Specificity: 0.9412
#
# Fold [7/10] Epoch [5/30], time cost: 15.5052,
#  Train Cross Loss: 0.1068, Train Contras Loss: 0.6039 Train acc:  0.9649,
#  Val Cross loss: 0.1031, Val Contras loss: 0.6083, Val accuracy: 0.9645, Sensitivity: 0.9750, Specificity: 0.9541
#
# Fold [7/10] Epoch [6/30], time cost: 15.7856,
#  Train Cross Loss: 0.1000, Train Contras Loss: 0.5535 Train acc:  0.9679,
#  Val Cross loss: 0.1043, Val Contras loss: 0.5892, Val accuracy: 0.9660, Sensitivity: 0.9819, Specificity: 0.9502
#
# Fold [7/10] Epoch [7/30], time cost: 15.9483,
#  Train Cross Loss: 0.0938, Train Contras Loss: 0.5217 Train acc:  0.9702,
#  Val Cross loss: 0.0850, Val Contras loss: 0.4879, Val accuracy: 0.9721, Sensitivity: 0.9880, Specificity: 0.9563
#
# Fold [7/10] Epoch [8/30], time cost: 15.9887,
#  Train Cross Loss: 0.0859, Train Contras Loss: 0.4794 Train acc:  0.9712,
#  Val Cross loss: 0.0738, Val Contras loss: 0.4021, Val accuracy: 0.9759, Sensitivity: 0.9880, Specificity: 0.9638
#
# Fold [7/10] Epoch [9/30], time cost: 15.7195,
#  Train Cross Loss: 0.0848, Train Contras Loss: 0.4536 Train acc:  0.9720,
#  Val Cross loss: 0.0951, Val Contras loss: 0.5160, Val accuracy: 0.9724, Sensitivity: 0.9953, Specificity: 0.9498
#
# Fold [7/10] Epoch [10/30], time cost: 15.8428,
#  Train Cross Loss: 0.0813, Train Contras Loss: 0.4392 Train acc:  0.9741,
#  Val Cross loss: 0.1001, Val Contras loss: 0.5099, Val accuracy: 0.9712, Sensitivity: 0.9841, Specificity: 0.9584
#
# Fold [7/10] Epoch [11/30], time cost: 15.9229,
#  Train Cross Loss: 0.0786, Train Contras Loss: 0.4153 Train acc:  0.9743,
#  Val Cross loss: 0.0837, Val Contras loss: 0.4224, Val accuracy: 0.9742, Sensitivity: 0.9797, Specificity: 0.9688
#
# Fold [7/10] Epoch [12/30], time cost: 15.8884,
#  Train Cross Loss: 0.0767, Train Contras Loss: 0.4010 Train acc:  0.9748,
#  Val Cross loss: 0.0859, Val Contras loss: 0.4741, Val accuracy: 0.9714, Sensitivity: 0.9906, Specificity: 0.9523
#
# Fold [7/10] Epoch [13/30], time cost: 15.8776,
#  Train Cross Loss: 0.0703, Train Contras Loss: 0.3760 Train acc:  0.9765,
#  Val Cross loss: 0.1144, Val Contras loss: 0.5029, Val accuracy: 0.9697, Sensitivity: 0.9743, Specificity: 0.9652
#
# Fold [7/10] Epoch [14/30], time cost: 15.9026,
#  Train Cross Loss: 0.0727, Train Contras Loss: 0.3706 Train acc:  0.9766,
#  Val Cross loss: 0.1292, Val Contras loss: 0.5958, Val accuracy: 0.9521, Sensitivity: 0.9395, Specificity: 0.9645
#
# Fold [7/10] Epoch [15/30], time cost: 15.8831,
#  Train Cross Loss: 0.0673, Train Contras Loss: 0.3485 Train acc:  0.9775,
#  Val Cross loss: 0.0737, Val Contras loss: 0.3941, Val accuracy: 0.9775, Sensitivity: 0.9873, Specificity: 0.9678
#
# Fold [7/10] Epoch [16/30], time cost: 15.8988,
#  Train Cross Loss: 0.0627, Train Contras Loss: 0.3323 Train acc:  0.9791,
# ...
#  Val Cross loss: 0.0562, Val Contras loss: 0.2909, Val accuracy: 0.9813, Sensitivity: 0.9904, Specificity: 0.9720
#
# Fold [8/10] Epoch [28/30], time cost: 14.6952,
#  Train Cross Loss: 0.0491, Train Contras Loss: 0.2429 Train acc:  0.9838,
#  Val Cross loss: 0.0583, Val Contras loss: 0.2985, Val accuracy: 0.9820, Sensitivity: 0.9897, Specificity: 0.9742
#
# Fold [8/10] Epoch [29/30], time cost: 14.6588,
#  Train Cross Loss: 0.0472, Train Contras Loss: 0.2361 Train acc:  0.9837,
#  Val Cross loss: 0.0518, Val Contras loss: 0.2220, Val accuracy: 0.9850, Sensitivity: 0.9886, Specificity: 0.9814
#
# Fold [8/10] Epoch [30/30], time cost: 14.6396,
#  Train Cross Loss: 0.0453, Train Contras Loss: 0.2226 Train acc:  0.9854,
#  Val Cross loss: 0.0598, Val Contras loss: 0.3161, Val accuracy: 0.9805, Sensitivity: 0.9939, Specificity: 0.9669
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 28 Acc: 0.9850477391460998 Sensitivity for pre-ictal: 0.9885836603638958 Specificity: 0.9814410480349345
# ***********
#
# Test Loss: 0.0635, Test accuracy: 0.9815, Sensitivity: 0.9858, Specificity: 0.9772
#
# Fold [9/10] Epoch [1/30], time cost: 14.5897,
#  Train Cross Loss: 0.2666, Train Contras Loss: 1.4018 Train acc:  0.9027,
#  Val Cross loss: 0.2070, Val Contras loss: 1.0617, Val accuracy: 0.9395, Sensitivity: 0.9947, Specificity: 0.8827
#
# Fold [9/10] Epoch [2/30], time cost: 14.6397,
#  Train Cross Loss: 0.1492, Train Contras Loss: 0.8341 Train acc:  0.9535,
#  Val Cross loss: 0.1547, Val Contras loss: 0.7951, Val accuracy: 0.9569, Sensitivity: 0.9929, Specificity: 0.9200
#
# Fold [9/10] Epoch [3/30], time cost: 14.8279,
#  Train Cross Loss: 0.1324, Train Contras Loss: 0.7355 Train acc:  0.9584,
#  Val Cross loss: 0.1127, Val Contras loss: 0.6630, Val accuracy: 0.9614, Sensitivity: 0.9858, Specificity: 0.9364
#
# Fold [9/10] Epoch [4/30], time cost: 14.5730,
#  Train Cross Loss: 0.1202, Train Contras Loss: 0.6588 Train acc:  0.9624,
#  Val Cross loss: 0.1387, Val Contras loss: 0.7874, Val accuracy: 0.9577, Sensitivity: 0.9911, Specificity: 0.9233
#
# Fold [9/10] Epoch [5/30], time cost: 14.6024,
#  Train Cross Loss: 0.1201, Train Contras Loss: 0.6516 Train acc:  0.9619,
#  Val Cross loss: 0.1105, Val Contras loss: 0.6298, Val accuracy: 0.9658, Sensitivity: 0.9932, Specificity: 0.9375
#
# Fold [9/10] Epoch [6/30], time cost: 14.5922,
#  Train Cross Loss: 0.1124, Train Contras Loss: 0.6199 Train acc:  0.9631,
#  Val Cross loss: 0.0976, Val Contras loss: 0.5403, Val accuracy: 0.9694, Sensitivity: 0.9954, Specificity: 0.9426
#
# Fold [9/10] Epoch [7/30], time cost: 14.6403,
#  Train Cross Loss: 0.1036, Train Contras Loss: 0.5672 Train acc:  0.9665,
#  Val Cross loss: 0.1026, Val Contras loss: 0.5777, Val accuracy: 0.9687, Sensitivity: 0.9897, Specificity: 0.9470
#
# Fold [9/10] Epoch [8/30], time cost: 14.5420,
#  Train Cross Loss: 0.0993, Train Contras Loss: 0.5539 Train acc:  0.9678,
#  Val Cross loss: 0.1110, Val Contras loss: 0.6042, Val accuracy: 0.9654, Sensitivity: 0.9964, Specificity: 0.9335
#
# Fold [9/10] Epoch [9/30], time cost: 14.7247,
#  Train Cross Loss: 0.0985, Train Contras Loss: 0.5453 Train acc:  0.9683,
#  Val Cross loss: 0.1006, Val Contras loss: 0.5488, Val accuracy: 0.9678, Sensitivity: 0.9733, Specificity: 0.9620
#
# Fold [9/10] Epoch [10/30], time cost: 14.7189,
#  Train Cross Loss: 0.0870, Train Contras Loss: 0.4746 Train acc:  0.9710,
#  Val Cross loss: 0.0912, Val Contras loss: 0.5485, Val accuracy: 0.9687, Sensitivity: 0.9794, Specificity: 0.9576
#
# Fold [9/10] Epoch [11/30], time cost: 13.9272,
#  Train Cross Loss: 0.0809, Train Contras Loss: 0.4313 Train acc:  0.9739,
#  Val Cross loss: 0.0947, Val Contras loss: 0.4724, Val accuracy: 0.9764, Sensitivity: 0.9879, Specificity: 0.9646
#
# Fold [9/10] Epoch [12/30], time cost: 13.8605,
#  Train Cross Loss: 0.0811, Train Contras Loss: 0.4247 Train acc:  0.9746,
#  Val Cross loss: 0.0867, Val Contras loss: 0.4799, Val accuracy: 0.9717, Sensitivity: 0.9957, Specificity: 0.9470
#
# Fold [9/10] Epoch [13/30], time cost: 13.9984,
#  Train Cross Loss: 0.0767, Train Contras Loss: 0.4050 Train acc:  0.9760,
#  Val Cross loss: 0.1004, Val Contras loss: 0.4315, Val accuracy: 0.9631, Sensitivity: 0.9815, Specificity: 0.9441
#
# Fold [9/10] Epoch [14/30], time cost: 13.8504,
#  Train Cross Loss: 0.0710, Train Contras Loss: 0.3651 Train acc:  0.9769,
#  Val Cross loss: 0.0881, Val Contras loss: 0.4944, Val accuracy: 0.9726, Sensitivity: 0.9808, Specificity: 0.9642
#
# Fold [9/10] Epoch [15/30], time cost: 13.7524,
#  Train Cross Loss: 0.0773, Train Contras Loss: 0.4022 Train acc:  0.9750,
#  Val Cross loss: 0.0903, Val Contras loss: 0.4972, Val accuracy: 0.9741, Sensitivity: 0.9865, Specificity: 0.9613
#
# Fold [9/10] Epoch [16/30], time cost: 13.7944,
#  Train Cross Loss: 0.0764, Train Contras Loss: 0.4054 Train acc:  0.9753,
#  Val Cross loss: 0.0860, Val Contras loss: 0.4587, Val accuracy: 0.9705, Sensitivity: 0.9915, Specificity: 0.9488
#
# Fold [9/10] Epoch [17/30], time cost: 13.7815,
#  Train Cross Loss: 0.0695, Train Contras Loss: 0.3702 Train acc:  0.9766,
#  Val Cross loss: 0.0700, Val Contras loss: 0.3757, Val accuracy: 0.9759, Sensitivity: 0.9869, Specificity: 0.9646
#
# Fold [9/10] Epoch [18/30], time cost: 13.6806,
#  Train Cross Loss: 0.0767, Train Contras Loss: 0.4026 Train acc:  0.9758,
#  Val Cross loss: 0.0884, Val Contras loss: 0.4586, Val accuracy: 0.9757, Sensitivity: 0.9911, Specificity: 0.9598
#
# Fold [9/10] Epoch [19/30], time cost: 13.8273,
#  Train Cross Loss: 0.0718, Train Contras Loss: 0.3771 Train acc:  0.9756,
#  Val Cross loss: 0.0825, Val Contras loss: 0.4613, Val accuracy: 0.9703, Sensitivity: 0.9822, Specificity: 0.9580
#
# Fold [9/10] Epoch [20/30], time cost: 13.9400,
#  Train Cross Loss: 0.0676, Train Contras Loss: 0.3503 Train acc:  0.9775,
#  Val Cross loss: 0.0658, Val Contras loss: 0.3672, Val accuracy: 0.9777, Sensitivity: 0.9900, Specificity: 0.9649
#
# Fold [9/10] Epoch [21/30], time cost: 14.2776,
#  Train Cross Loss: 0.0591, Train Contras Loss: 0.3015 Train acc:  0.9805,
#  Val Cross loss: 0.0787, Val Contras loss: 0.3835, Val accuracy: 0.9746, Sensitivity: 0.9794, Specificity: 0.9697
#
# Fold [9/10] Epoch [22/30], time cost: 14.0786,
#  Train Cross Loss: 0.0628, Train Contras Loss: 0.3150 Train acc:  0.9803,
#  Val Cross loss: 0.0740, Val Contras loss: 0.3952, Val accuracy: 0.9730, Sensitivity: 0.9808, Specificity: 0.9649
#
# Fold [9/10] Epoch [23/30], time cost: 13.9296,
#  Train Cross Loss: 0.0584, Train Contras Loss: 0.2941 Train acc:  0.9811,
#  Val Cross loss: 0.0698, Val Contras loss: 0.3516, Val accuracy: 0.9796, Sensitivity: 0.9936, Specificity: 0.9653
#
# Fold [9/10] Epoch [24/30], time cost: 13.9274,
#  Train Cross Loss: 0.0574, Train Contras Loss: 0.2968 Train acc:  0.9819,
#  Val Cross loss: 0.0792, Val Contras loss: 0.4039, Val accuracy: 0.9723, Sensitivity: 0.9719, Specificity: 0.9726
#
# Fold [9/10] Epoch [25/30], time cost: 13.7555,
#  Train Cross Loss: 0.0547, Train Contras Loss: 0.2776 Train acc:  0.9837,
#  Val Cross loss: 0.1370, Val Contras loss: 0.5956, Val accuracy: 0.9679, Sensitivity: 0.9979, Specificity: 0.9372
#
# Fold [9/10] Epoch [26/30], time cost: 13.9481,
#  Train Cross Loss: 0.0543, Train Contras Loss: 0.2715 Train acc:  0.9823,
#  Val Cross loss: 0.0669, Val Contras loss: 0.3594, Val accuracy: 0.9739, Sensitivity: 0.9844, Specificity: 0.9631
#
# Fold [9/10] Epoch [27/30], time cost: 13.7739,
#  Train Cross Loss: 0.0562, Train Contras Loss: 0.2809 Train acc:  0.9817,
#  Val Cross loss: 0.0910, Val Contras loss: 0.5016, Val accuracy: 0.9719, Sensitivity: 0.9659, Specificity: 0.9781
#
# Fold [9/10] Epoch [28/30], time cost: 13.8239,
#  Train Cross Loss: 0.0629, Train Contras Loss: 0.3067 Train acc:  0.9805,
#  Val Cross loss: 0.0752, Val Contras loss: 0.4225, Val accuracy: 0.9724, Sensitivity: 0.9808, Specificity: 0.9638
#
# Fold [9/10] Epoch [29/30], time cost: 13.9142,
#  Train Cross Loss: 0.0548, Train Contras Loss: 0.2706 Train acc:  0.9815,
#  Val Cross loss: 0.0656, Val Contras loss: 0.3176, Val accuracy: 0.9809, Sensitivity: 0.9964, Specificity: 0.9649
#
# Fold [9/10] Epoch [30/30], time cost: 13.8968,
#  Train Cross Loss: 0.0501, Train Contras Loss: 0.2506 Train acc:  0.9843,
#  Val Cross loss: 0.0657, Val Contras loss: 0.3256, Val accuracy: 0.9818, Sensitivity: 0.9940, Specificity: 0.9693
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 29 Acc: 0.9818050801657359 Sensitivity for pre-ictal: 0.9939587775408671 Specificity: 0.969309462915601
# ***********
#
# Test Loss: 0.0630, Test accuracy: 0.9799, Sensitivity: 0.9884, Specificity: 0.9714
#
# Fold [10/10] Epoch [1/30], time cost: 13.9866,
#  Train Cross Loss: 0.2541, Train Contras Loss: 1.3604 Train acc:  0.9043,
#  Val Cross loss: 0.1517, Val Contras loss: 0.8454, Val accuracy: 0.9497, Sensitivity: 0.9756, Specificity: 0.9236
#
# Fold [10/10] Epoch [2/30], time cost: 14.0229,
#  Train Cross Loss: 0.1388, Train Contras Loss: 0.7963 Train acc:  0.9523,
#  Val Cross loss: 0.1461, Val Contras loss: 0.7582, Val accuracy: 0.9530, Sensitivity: 0.9760, Specificity: 0.9297
#
# Fold [10/10] Epoch [3/30], time cost: 13.9690,
#  Train Cross Loss: 0.1246, Train Contras Loss: 0.7160 Train acc:  0.9574,
#  Val Cross loss: 0.2199, Val Contras loss: 1.1897, Val accuracy: 0.8980, Sensitivity: 0.8323, Specificity: 0.9645
#
# Fold [10/10] Epoch [4/30], time cost: 13.8606,
#  Train Cross Loss: 0.1131, Train Contras Loss: 0.6266 Train acc:  0.9624,
#  Val Cross loss: 0.1004, Val Contras loss: 0.5537, Val accuracy: 0.9672, Sensitivity: 0.9871, Specificity: 0.9471
#
# Fold [10/10] Epoch [5/30], time cost: 13.9233,
#  Train Cross Loss: 0.1031, Train Contras Loss: 0.5459 Train acc:  0.9657,
#  Val Cross loss: 0.1062, Val Contras loss: 0.5601, Val accuracy: 0.9632, Sensitivity: 0.9907, Specificity: 0.9355
#
# Fold [10/10] Epoch [6/30], time cost: 14.6831,
#  Train Cross Loss: 0.0922, Train Contras Loss: 0.5034 Train acc:  0.9697,
#  Val Cross loss: 0.0924, Val Contras loss: 0.5202, Val accuracy: 0.9629, Sensitivity: 0.9617, Specificity: 0.9641
#
# Fold [10/10] Epoch [7/30], time cost: 13.9693,
#  Train Cross Loss: 0.0888, Train Contras Loss: 0.4784 Train acc:  0.9713,
#  Val Cross loss: 0.0816, Val Contras loss: 0.4625, Val accuracy: 0.9726, Sensitivity: 0.9903, Specificity: 0.9547
#
# Fold [10/10] Epoch [8/30], time cost: 13.2593,
#  Train Cross Loss: 0.0876, Train Contras Loss: 0.4677 Train acc:  0.9705,
#  Val Cross loss: 0.0820, Val Contras loss: 0.4541, Val accuracy: 0.9735, Sensitivity: 0.9893, Specificity: 0.9576
#
# Fold [10/10] Epoch [9/30], time cost: 13.0558,
#  Train Cross Loss: 0.0782, Train Contras Loss: 0.4119 Train acc:  0.9740,
#  Val Cross loss: 0.0845, Val Contras loss: 0.4726, Val accuracy: 0.9732, Sensitivity: 0.9918, Specificity: 0.9543
#
# Fold [10/10] Epoch [10/30], time cost: 13.1474,
#  Train Cross Loss: 0.0757, Train Contras Loss: 0.4013 Train acc:  0.9752,
#  Val Cross loss: 0.0665, Val Contras loss: 0.3503, Val accuracy: 0.9760, Sensitivity: 0.9871, Specificity: 0.9649
#
# Fold [10/10] Epoch [11/30], time cost: 13.0886,
#  Train Cross Loss: 0.0741, Train Contras Loss: 0.3843 Train acc:  0.9756,
#  Val Cross loss: 0.0658, Val Contras loss: 0.3624, Val accuracy: 0.9795, Sensitivity: 0.9957, Specificity: 0.9630
#
# Fold [10/10] Epoch [12/30], time cost: 13.1105,
#  Train Cross Loss: 0.0731, Train Contras Loss: 0.3731 Train acc:  0.9759,
#  Val Cross loss: 0.0758, Val Contras loss: 0.4063, Val accuracy: 0.9769, Sensitivity: 0.9964, Specificity: 0.9572
#
# Fold [10/10] Epoch [13/30], time cost: 13.1036,
#  Train Cross Loss: 0.0673, Train Contras Loss: 0.3450 Train acc:  0.9779,
#  Val Cross loss: 0.0751, Val Contras loss: 0.3737, Val accuracy: 0.9787, Sensitivity: 0.9903, Specificity: 0.9670
#
# Fold [10/10] Epoch [14/30], time cost: 13.1794,
#  Train Cross Loss: 0.0688, Train Contras Loss: 0.3511 Train acc:  0.9773,
#  Val Cross loss: 0.0556, Val Contras loss: 0.3035, Val accuracy: 0.9809, Sensitivity: 0.9928, Specificity: 0.9688
#
# Fold [10/10] Epoch [15/30], time cost: 13.2571,
#  Train Cross Loss: 0.0659, Train Contras Loss: 0.3345 Train acc:  0.9791,
#  Val Cross loss: 0.0754, Val Contras loss: 0.3981, Val accuracy: 0.9751, Sensitivity: 0.9936, Specificity: 0.9565
#
# Fold [10/10] Epoch [16/30], time cost: 13.1934,
#  Train Cross Loss: 0.0658, Train Contras Loss: 0.3278 Train acc:  0.9787,
#  Val Cross loss: 0.0658, Val Contras loss: 0.3498, Val accuracy: 0.9784, Sensitivity: 0.9910, Specificity: 0.9656
#
# Fold [10/10] Epoch [17/30], time cost: 13.1492,
#  Train Cross Loss: 0.0609, Train Contras Loss: 0.3045 Train acc:  0.9796,
#  Val Cross loss: 0.0649, Val Contras loss: 0.3417, Val accuracy: 0.9795, Sensitivity: 0.9910, Specificity: 0.9678
#
# Fold [10/10] Epoch [18/30], time cost: 13.1652,
#  Train Cross Loss: 0.0597, Train Contras Loss: 0.2988 Train acc:  0.9805,
#  Val Cross loss: 0.0635, Val Contras loss: 0.3123, Val accuracy: 0.9775, Sensitivity: 0.9946, Specificity: 0.9601
#
# Fold [10/10] Epoch [19/30], time cost: 13.1961,
#  Train Cross Loss: 0.0607, Train Contras Loss: 0.2993 Train acc:  0.9798,
#  Val Cross loss: 0.0690, Val Contras loss: 0.3377, Val accuracy: 0.9814, Sensitivity: 0.9925, Specificity: 0.9703
#
# Fold [10/10] Epoch [20/30], time cost: 13.1947,
#  Train Cross Loss: 0.0519, Train Contras Loss: 0.2555 Train acc:  0.9834,
#  Val Cross loss: 0.0717, Val Contras loss: 0.3509, Val accuracy: 0.9787, Sensitivity: 0.9885, Specificity: 0.9688
#
# Fold [10/10] Epoch [21/30], time cost: 13.1798,
#  Train Cross Loss: 0.0593, Train Contras Loss: 0.2863 Train acc:  0.9805,
#  Val Cross loss: 0.0693, Val Contras loss: 0.3575, Val accuracy: 0.9778, Sensitivity: 0.9925, Specificity: 0.9630
#
# Fold [10/10] Epoch [22/30], time cost: 13.1340,
#  Train Cross Loss: 0.0510, Train Contras Loss: 0.2521 Train acc:  0.9830,
#  Val Cross loss: 0.0604, Val Contras loss: 0.3311, Val accuracy: 0.9786, Sensitivity: 0.9817, Specificity: 0.9754
#
# Fold [10/10] Epoch [23/30], time cost: 13.2115,
#  Train Cross Loss: 0.0500, Train Contras Loss: 0.2387 Train acc:  0.9831,
#  Val Cross loss: 0.0654, Val Contras loss: 0.3185, Val accuracy: 0.9798, Sensitivity: 0.9964, Specificity: 0.9630
#
# Fold [10/10] Epoch [24/30], time cost: 13.0089,
#  Train Cross Loss: 0.0499, Train Contras Loss: 0.2432 Train acc:  0.9837,
#  Val Cross loss: 0.1425, Val Contras loss: 0.5212, Val accuracy: 0.9652, Sensitivity: 0.9599, Specificity: 0.9707
#
# Fold [10/10] Epoch [25/30], time cost: 13.0732,
#  Train Cross Loss: 0.0505, Train Contras Loss: 0.2444 Train acc:  0.9837,
#  Val Cross loss: 0.0710, Val Contras loss: 0.3395, Val accuracy: 0.9750, Sensitivity: 0.9735, Specificity: 0.9764
#
# Fold [10/10] Epoch [26/30], time cost: 12.9904,
#  Train Cross Loss: 0.0480, Train Contras Loss: 0.2437 Train acc:  0.9834,
#  Val Cross loss: 0.0676, Val Contras loss: 0.3406, Val accuracy: 0.9786, Sensitivity: 0.9842, Specificity: 0.9728
#
# Fold [10/10] Epoch [27/30], time cost: 13.1637,
#  Train Cross Loss: 0.0475, Train Contras Loss: 0.2256 Train acc:  0.9838,
#  Val Cross loss: 0.0803, Val Contras loss: 0.4068, Val accuracy: 0.9678, Sensitivity: 0.9556, Specificity: 0.9801
#
# Fold [10/10] Epoch [28/30], time cost: 13.2575,
#  Train Cross Loss: 0.0462, Train Contras Loss: 0.2171 Train acc:  0.9846,
#  Val Cross loss: 0.0788, Val Contras loss: 0.3665, Val accuracy: 0.9769, Sensitivity: 0.9964, Specificity: 0.9572
#
# Fold [10/10] Epoch [29/30], time cost: 13.0854,
#  Train Cross Loss: 0.0461, Train Contras Loss: 0.2186 Train acc:  0.9850,
#  Val Cross loss: 0.0684, Val Contras loss: 0.3183, Val accuracy: 0.9762, Sensitivity: 0.9860, Specificity: 0.9663
#
# Fold [10/10] Epoch [30/30], time cost: 13.0554,
#  Train Cross Loss: 0.0428, Train Contras Loss: 0.2005 Train acc:  0.9864,
#  Val Cross loss: 0.0612, Val Contras loss: 0.2989, Val accuracy: 0.9818, Sensitivity: 0.9918, Specificity: 0.9717
# ['EEG O1', 'EEG T6', 'EEG T5', 'EEG F8', 'EEG P4', 'EEG C4', 'EEG A2', 'EEG A1']
#
# ***********
# Best epoch: 29 Acc: 0.9818050801657359 Sensitivity for pre-ictal: 0.9917592260838409 Specificity: 0.9717391304347827
# ***********
#
# Test Loss: 0.0569, Test accuracy: 0.9802, Sensitivity: 0.9935, Specificity: 0.9668
#
#
# Avg test acc: 0.9800, avg test sensitivity: 0.9902, avg test specificity: 0.9698
